# %% [markdown]
# # Features quering with filtering based on properties
#
# Common geospatial services include filtering by the Area of Interest.
# It is important they do as the service usually contain vast amount of data and must be queried carefully.
# Modern interfaces like OGC API Features provide efficient
# However, with the variety of extensions of generic interfaces, like OGC API Features (previously WFS), custom properties are added that are not neccesarily indexed and queryable depending on the backend and service configuration. Additionally, they can be exended in various ways and the exact mapping between data and their semantic can be ambiguous.
#
# In any case, data queried can be analysed including properties to filter, classify, sort, join etc.
# Sparql language gives
#
# In this examples, generic OGC API fertures is extended with custom, domain specific properties. Ocean Information Model integration is done though JSON-LD context that can be set in other place (here are OGC Incubator Building blocks). Example shows how data can be queries and processed on the client endpoint

# %%
#check if all the packages are installed
# !pip install folium rdflib streamlit-folium
# Out:
# Requirement already satisfied: folium in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: rdflib in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (7.1.1)
# Collecting streamlit-folium
#   Downloading streamlit_folium-0.23.2-py3-none-any.whl.metadata (414 bytes)
# Requirement already satisfied: branca>=0.6.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from folium) (2.1.1)
# Requirement already satisfied: requests in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rdflib) (3.1.4)
# Collecting streamlit>=1.13.0 (from streamlit-folium)
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Collecting altair<6,>=4.0 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit>=1.13.0->streamlit-folium)
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (11.0.0)
# Collecting protobuf<6,>=3.20 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading pyarrow-18.0.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting rich<14,>=10.14.0 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=1.13.0->streamlit-folium)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from streamlit>=1.13.0->streamlit-folium) (6.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from requests->folium) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from requests->folium) (2024.8.30)
# Collecting jsonschema>=3.0 (from altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading narwhals-1.13.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2024.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium) (2.18.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (24.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading rpds_py-0.21.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (1.16.0)
# Downloading streamlit_folium-0.23.2-py3-none-any.whl (328 kB)
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 7.3 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl (414 kB)
# Downloading pyarrow-18.0.0-cp311-cp311-macosx_12_0_arm64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 12.8 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 13.6 MB/s eta 0:00:00a 0:00:01
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading narwhals-1.13.5-py3-none-any.whl (208 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (318 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: toml, tenacity, smmap, rpds-py, pyarrow, protobuf, narwhals, mdurl, cachetools, blinker, referencing, pydeck, markdown-it-py, gitdb, rich, jsonschema-specifications, gitpython, jsonschema, altair, streamlit, streamlit-folium
# Successfully installed altair-5.4.1 blinker-1.9.0 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.13.5 protobuf-5.28.3 pyarrow-18.0.0 pydeck-0.9.1 referencing-0.35.1 rich-13.9.4 rpds-py-0.21.0 smmap-5.0.1 streamlit-1.40.1 streamlit-folium-0.23.2 tenacity-9.0.0 toml-0.10.2

# %%
# Import necessary libraries
import requests
import json

#Define the HTTP endpoint URL, this static data is test proven, it can be changed to live features service and query parameters can be provided inline
url = "https://ogcincubator.github.io/iliad-apis-features/build/tests/hosted/iliad/api/features/iliad-jellyfish/example_1_1.json"
# Fetch data from the HTTP endpoint
response = requests.get(url)
data = response.json()
data
# Out:
# {'@id': '1-18-527-Phyllorhiza_punctata',
#  'type': 'Feature',
#  'featureType': 'sosa:Observation',
#  'geometry': {'type': 'Point', 'coordinates': [31.80691, 34.634776]},
#  'properties': {'label': {'en': 'Jelly fish observation #1 location id: 18 sensor: 527 species: Phyllorhiza punctata'},
#   'phenomenonTime': '2011-07-01T09:00:00',
#   'resultTime': '2011-07-01T09:00:00',
#   'observedProperty': 'jellyFishAbundanceProperty',
#   'hasFeatureOfInterest': '1-18',
#   'hasResult': {'densityOfJF': 'Some',
#    'quantityOfJF': 50,
#    'sampleSizeValue': '10-30',
#    'speciesScientificName': 'Phyllorhiza punctata',
#    'wormsConcept': 'https://marinespecies.org/aphia.php?p=taxdetails&id=135298',
#    'stingByJF': 'Unspecified',
#    'beachedJF': '1'}}}

# %% [markdown]
# # map visualisation
# Thanks to the standard format of data output, it can be easily visualised on client application like QGIS, ArcGIS or web frameworks like Openlayers or Leaflet
# Let's see how the data looks like in this case.
# You'll see that this small sample is representing one occurence, represented as 'feature' in geospatial language.
#
# ## data fixing
# In the previous example, we've detected that the latitude and longitude were incorrect, it should not occur with the real data but let's fix example.
# in the geojson, coordinates of point shall represent longiture and latitude
# 'coordinates': [31.80691, 34.634776] is 34°38'05.2"N 31°48'24.9"E, somewhere around Cyprus
# 'coordinates': [34.634776, 31.80691] is 34°38'05.2"E 31°48'24.9"N, somewhere around on the Israel coast

# %%
#coordinates swap
lat = data['geometry']['coordinates'][0]
data['geometry']['coordinates'][0] = data['geometry']['coordinates'][1]
data['geometry']['coordinates'][1] = lat
data
# Out:
# {'@id': '1-18-527-Phyllorhiza_punctata',
#  'type': 'Feature',
#  'featureType': 'sosa:Observation',
#  'geometry': {'type': 'Point', 'coordinates': [34.634776, 31.80691]},
#  'properties': {'label': {'en': 'Jelly fish observation #1 location id: 18 sensor: 527 species: Phyllorhiza punctata'},
#   'phenomenonTime': '2011-07-01T09:00:00',
#   'resultTime': '2011-07-01T09:00:00',
#   'observedProperty': 'jellyFishAbundanceProperty',
#   'hasFeatureOfInterest': '1-18',
#   'hasResult': {'densityOfJF': 'Some',
#    'quantityOfJF': 50,
#    'sampleSizeValue': '10-30',
#    'speciesScientificName': 'Phyllorhiza punctata',
#    'wormsConcept': 'https://marinespecies.org/aphia.php?p=taxdetails&id=135298',
#    'stingByJF': 'Unspecified',
#    'beachedJF': '1'}}}

# %%
import folium

#create visualisation function and use it first time
def map_features(data, center, zoom):
    # Create a map centered around the coordinates
    m = folium.Map(location = center, zoom_start = zoom)
    # Add GeoJSON data to the map
    folium.GeoJson(data, name="geojson").add_to(m)
    # Add a layer control panel to the map
    folium.LayerControl().add_to(m)
    #return map in case it needs to be updated
    return m 

# Display the map in a Jupyter Notebook (if using one)
map_features(data=data, center=[31.80691, 34.634776],zoom=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a14f1b7ec47dc4fa0cb8daccbf22e0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a14f1b7ec47dc4fa0cb8daccbf22e0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a14f1b7ec47dc4fa0cb8daccbf22e0e = L.map(
#                 &quot;map_6a14f1b7ec47dc4fa0cb8daccbf22e0e&quot;,
#                 {
#                     center: [31.80691, 34.634776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a19fea464e800275deabc77b0191e130 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a19fea464e800275deabc77b0191e130.addTo(map_6a14f1b7ec47dc4fa0cb8daccbf22e0e);
#
#
#
#         function geo_json_65ee4867304f39c88f33eb05cc9540a1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_65ee4867304f39c88f33eb05cc9540a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_65ee4867304f39c88f33eb05cc9540a1_onEachFeature,
#
#         });
#
#         function geo_json_65ee4867304f39c88f33eb05cc9540a1_add (data) {
#             geo_json_65ee4867304f39c88f33eb05cc9540a1
#                 .addData(data);
#         }
#             geo_json_65ee4867304f39c88f33eb05cc9540a1_add({&quot;@id&quot;: &quot;1-18-527-Phyllorhiza_punctata&quot;, &quot;featureType&quot;: &quot;sosa:Observation&quot;, &quot;geometry&quot;: {&quot;coordinates&quot;: [34.634776, 31.80691], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;hasFeatureOfInterest&quot;: &quot;1-18&quot;, &quot;hasResult&quot;: {&quot;beachedJF&quot;: &quot;1&quot;, &quot;densityOfJF&quot;: &quot;Some&quot;, &quot;quantityOfJF&quot;: 50, &quot;sampleSizeValue&quot;: &quot;10-30&quot;, &quot;speciesScientificName&quot;: &quot;Phyllorhiza punctata&quot;, &quot;stingByJF&quot;: &quot;Unspecified&quot;, &quot;wormsConcept&quot;: &quot;https://marinespecies.org/aphia.php?p=taxdetails\u0026id=135298&quot;}, &quot;label&quot;: {&quot;en&quot;: &quot;Jelly fish observation #1 location id: 18 sensor: 527 species: Phyllorhiza punctata&quot;}, &quot;observedProperty&quot;: &quot;jellyFishAbundanceProperty&quot;, &quot;phenomenonTime&quot;: &quot;2011-07-01T09:00:00&quot;, &quot;resultTime&quot;: &quot;2011-07-01T09:00:00&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_65ee4867304f39c88f33eb05cc9540a1.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_65ee4867304f39c88f33eb05cc9540a1.addTo(map_6a14f1b7ec47dc4fa0cb8daccbf22e0e);
#
#
#             var layer_control_a385b6c941194d4e5c3bf95c9688a6d4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a19fea464e800275deabc77b0191e130,
#                 },
#                 overlays :  {
#                     &quot;geojson&quot; : geo_json_65ee4867304f39c88f33eb05cc9540a1,
#                 },
#             };
#             let layer_control_a385b6c941194d4e5c3bf95c9688a6d4 = L.control.layers(
#                 layer_control_a385b6c941194d4e5c3bf95c9688a6d4_layers.base_layers,
#                 layer_control_a385b6c941194d4e5c3bf95c9688a6d4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6a14f1b7ec47dc4fa0cb8daccbf22e0e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ld_context = "https://ogcincubator.github.io/iliad-apis-features/build/annotated/hosted/iliad/api/features/iliad-jellyfish/context.jsonld"
# Fetch data from the HTTP endpoint
response = requests.get(ld_context)
context = response.json()
context
# Out:
# {'@context': {'@base': 'https://w3id.org/iliad/jellyfish/observation/',
#   'resultTime': 'sosa:resultTime',
#   'phenomenonTime': {'@id': 'sosa:phenomenonTime', '@type': '@id'},
#   'hasFeatureOfInterest': {'@context': {'@base': 'https://w3id.org/iliad/jellyfish/feature/'},
#    '@id': 'sosa:hasFeatureOfInterest',
#    '@type': '@id'},
#   'observedProperty': {'@context': {'@base': 'https://w3id.org/iliad/jellyfish/property/'},
#    '@id': 'sosa:observedProperty',
#    '@type': '@id'},
#   'usedProcedure': {'@id': 'sosa:usedProcedure', '@type': '@id'},
#   'madeBySensor': {'@id': 'sosa:madeBySensor', '@type': '@id'},
#   'id': '@id',
#   'properties': '@nest',
#   'featureType': '@type',
#   'ActuatableProperty': {'@id': 'sosa:ActuatableProperty', '@type': '@id'},
#   'Actuation': {'@id': 'sosa:Actuation', '@type': '@id'},
#   'ActuationCollection': {'@id': 'sosa:ActuationCollection', '@type': '@id'},
#   'Actuator': {'@id': 'sosa:Actuator', '@type': '@id'},
#   'Deployment': {'@id': 'sosa:Deployment', '@type': '@id'},
#   'Execution': {'@id': 'sosa:Execution', '@type': '@id'},
#   'FeatureOfInterest': {'@id': 'sosa:FeatureOfInterest', '@type': '@id'},
#   'ObservableProperty': {'@id': 'sosa:ObservableProperty', '@type': '@id'},
#   'Observation': {'@id': 'sosa:Observation', '@type': '@id'},
#   'ObservationCollection': {'@id': 'sosa:ObservationCollection',
#    '@type': '@id'},
#   'Platform': {'@id': 'sosa:Platform', '@type': '@id'},
#   'Property': {'@id': 'sosa:Property', '@type': '@id'},
#   'Procedure ': {'@id': 'sosa:Procedure', '@type': '@id'},
#   'Sample': {'@id': 'sosa:Sample', '@type': '@id'},
#   'SampleCollection': {'@id': 'sosa:SampleCollection', '@type': '@id'},
#   'Sampler': {'@id': 'sosa:Sampler', '@type': '@id'},
#   'Sampling': {'@id': 'sosa:Sampling', '@type': '@id'},
#   'Sensor': {'@id': 'sosa:Sensor', '@type': '@id'},
#   'Stimulus': {'@id': 'sosa:Stimulus', '@type': '@id'},
#   'System': {'@id': 'sosa:System', '@type': '@id'},
#   'actsOnProperty': {'@id': 'sosa:actsOnProperty', '@type': '@id'},
#   'deployedOnPlatform': {'@id': 'sosa:deployedOnPlatform', '@type': '@id'},
#   'deployedSystem': {'@id': 'sosa:deployedSystem', '@type': '@id'},
#   'detects': {'@id': 'sosa:detects', '@type': '@id'},
#   'features': {'@id': 'sosa:hasMember',
#    '@type': '@id',
#    '@container': '@set',
#    '@context': {'hasFeatureOfInterest': {'@id': 'sosa:hasFeatureOfInterest',
#      '@type': '@id'},
#     'hasResult': {'@id': 'sosa:hasResult', '@type': '@id'}}},
#   'forProperty': {'@id': 'sosa:forProperty', '@type': '@id'},
#   'hasDeployment': {'@id': 'sosa:hasDeployment', '@type': '@id'},
#   'hasInput': {'@id': 'sosa:hasInput', '@type': '@id'},
#   'hasMember': {'@id': 'sosa:hasMember',
#    '@type': '@id',
#    '@context': {'hasFeatureOfInterest': {'@id': 'sosa:hasFeatureOfInterest',
#      '@type': '@id'},
#     'hasResult': {'@id': 'sosa:hasResult', '@type': '@id'}}},
#   'hasOriginalSample': {'@id': 'sosa:hasOriginalSample', '@type': '@id'},
#   'hasOutput': {'@id': 'sosa:hasOutput', '@type': '@id'},
#   'hasProperty': {'@id': 'sosa:hasProperty', '@type': '@id'},
#   'hasResult': {'@id': 'sosa:hasResult',
#    '@type': '@id',
#    '@context': {'quantityOfJF': 'jf-property:quantityOfJF',
#     'densityOfJF': {'@context': {'@base': 'https://w3id.org/iliad/jellyfish/property/densityOfJF/'},
#      '@id': 'jf-property:densityOfJF',
#      '@type': '@id'},
#     'stingByJF': 'jf-property:stingByJF',
#     'beachedJF': 'jf-property:beachedJF'}},
#   'hasResultQuality': {'@id': 'sosa:hasResultQuality', '@type': '@id'},
#   'hasSample': {'@id': 'sosa:hasSample', '@type': '@id'},
#   'hasSampledFeature': {'@id': 'sosa:hasSampledFeature', '@type': '@id'},
#   'hasSimpleResult': {'@id': 'sosa:hasSimpleResult', '@type': '@id'},
#   'hasSubSystem': {'@id': 'sosa:hasSubSystem',
#    '@type': '@id',
#    '@container': '@set'},
#   'hasUltimateFeatureOfInterest': {'@id': 'sosa:hasUltimateFeatureOfInterest',
#    '@type': '@id'},
#   'hosts': {'@id': 'sosa:hosts', '@type': '@id', '@container': '@set'},
#   'implementedBy': {'@id': 'sosa:implementedBy', '@type': '@id'},
#   'implements': {'@id': 'sosa:implements', '@type': '@id'},
#   'inDeployment': {'@id': 'sosa:inDeployment', '@type': '@id'},
#   'isActedOnBy': {'@id': 'sosa:isActedOnBy', '@type': '@id'},
#   'isFeatureOfInterestOf': {'@id': 'sosa:isFeatureOfInterestOf',
#    '@type': '@id'},
#   'isHostedBy': {'@id': 'sosa:isHostedBy', '@type': '@id'},
#   'isObservedBy': {'@id': 'sosa:isObservedBy', '@type': '@id'},
#   'isPropertyOf': {'@id': 'sosa:isPropertyOf', '@type': '@id'},
#   'isProxyFor': {'@id': 'sosa:isProxyFor', '@type': '@id'},
#   'isResultOf': {'@id': 'sosa:isResultOf', '@type': '@id'},
#   'isResultOfMadeBySampler': {'@id': 'sosa:isResultOfMadeBySampler',
#    '@type': '@id'},
#   'isResultOfUsedProcedure': {'@id': 'sosa:isResultOfUsedProcedure',
#    '@type': '@id'},
#   'isSampleOf': {'@id': 'sosa:isSampleOf', '@type': '@id'},
#   'madeActuation': {'@id': 'sosa:madeActuation', '@type': '@id'},
#   'madeByActuator': {'@id': 'sosa:madeByActuator', '@type': '@id'},
#   'madeBySampler': {'@id': 'sosa:madeBySampler', '@type': '@id'},
#   'madeObservation': {'@id': 'sosa:madeObservation', '@type': '@id'},
#   'madeSampling': {'@id': 'sosa:madeSampling', '@type': '@id'},
#   'observes': {'@id': 'sosa:observes', '@type': '@id'},
#   'wasOriginatedBy': {'@id': 'sosa:wasOriginatedBy', '@type': '@id'},
#   'Accuracy': {'@id': 'ssn-system:Accuracy', '@type': '@id'},
#   'ActuationRange': {'@id': 'ssn-system:ActuationRange', '@type': '@id'},
#   'BatteryLifetime': {'@id': 'ssn-system:BatteryLifetime', '@type': '@id'},
#   'DetectionLimit': {'@id': 'ssn-system:DetectionLimit', '@type': '@id'},
#   'Drift': {'@id': 'ssn-system:Drift', '@type': '@id'},
#   'Frequency': {'@id': 'ssn-system:Frequency', '@type': '@id'},
#   'Latency': {'@id': 'ssn-system:Latency', '@type': '@id'},
#   'MaintenanceSchedule': {'@id': 'ssn-system:MaintenanceSchedule',
#    '@type': '@id'},
#   'MeasurementRange': {'@id': 'ssn-system:MeasurementRange', '@type': '@id'},
#   'OperatingPowerRange': {'@id': 'ssn-system:OperatingPowerRange',
#    '@type': '@id'},
#   'OperatingProperty': {'@id': 'ssn-system:OperatingProperty', '@type': '@id'},
#   'OperatingRange': {'@id': 'ssn-system:OperatingRange', '@type': '@id'},
#   'Precision': {'@id': 'ssn-system:Precision', '@type': '@id'},
#   'Resolution': {'@id': 'ssn-system:Resolution', '@type': '@id'},
#   'ResponseTime': {'@id': 'ssn-system:ResponseTime', '@type': '@id'},
#   'Selectivity': {'@id': 'ssn-system:Selectivity', '@type': '@id'},
#   'Sensitivity': {'@id': 'ssn-system:Sensitivity', '@type': '@id'},
#   'SurvivalProperty': {'@id': 'ssn-system:SurvivalProperty', '@type': '@id'},
#   'SystemLifetime': {'@id': 'ssn-system:SystemLifetime', '@type': '@id'},
#   'SurvivalRange': {'@id': 'ssn-system:SurvivalRange', '@type': '@id'},
#   'SystemCapability': {'@id': 'ssn-system:SystemCapability', '@type': '@id'},
#   'SystemProperty': {'@id': 'ssn-system:SystemProperty', '@type': '@id'},
#   'hasOperatingProperty': {'@id': 'ssn-system:hasOperatingProperty',
#    '@type': '@id'},
#   'hasOperatingRange': {'@id': 'ssn-system:hasOperatingRange', '@type': '@id'},
#   'hasSurvivalProperty': {'@id': 'ssn-system:hasSurvivalProperty',
#    '@type': '@id'},
#   'hasSystemCapability': {'@id': 'ssn-system:hasSystemCapability',
#    '@type': '@id'},
#   'hasSystemProperty': {'@id': 'ssn-system:hasSystemProperty', '@type': '@id'},
#   'hasSurvivalRange': {'@id': 'ssn-system:hasSurvivalRange', '@type': '@id'},
#   'inCondition': {'@id': 'ssn-system:inCondition', '@type': '@id'},
#   'qualityOfObservation': {'@id': 'ssn-system:qualityOfObservation',
#    '@type': '@id'},
#   'label': {'@id': 'rdfs:label', '@container': '@language'},
#   'sampleSizeValue': 'iliad:sampleSizeValue',
#   'speciesScientificName': 'iliad:speciesScientificName',
#   'wormsConcept': {'@id': 'iliad:wormsConcept', '@type': '@id'},
#   'type': '@type',
#   'geometry': 'geojson:geometry',
#   'bbox': {'@container': '@list', '@id': 'geojson:bbox'},
#   'Feature': 'geojson:Feature',
#   'FeatureCollection': 'geojson:FeatureCollection',
#   'GeometryCollection': 'geojson:GeometryCollection',
#   'LineString': 'geojson:LineString',
#   'MultiLineString': 'geojson:MultiLineString',
#   'MultiPoint': 'geojson:MultiPoint',
#   'MultiPolygon': 'geojson:MultiPolygon',
#   'Point': 'geojson:Point',
#   'Polygon': 'geojson:Polygon',
#   'links': {'@context': {'href': {'@type': '@id', '@id': 'oa:hasTarget'},
#     'rel': {'@context': {'@base': 'http://www.iana.org/assignments/relation/'},
#      '@id': 'http://www.iana.org/assignments/relation',
#      '@type': '@id'},
#     'type': 'dct:type',
#     'hreflang': 'dct:language',
#     'title': 'rdfs:label',
#     'length': 'dct:extent'},
#    '@id': 'rdfs:seeAlso'},
#   'time': {'@context': {'date': {'@id': 'owlTime:hasTime',
#      '@type': 'xsd:date'},
#     'timestamp': {'@id': 'owlTime:hasTime', '@type': 'xsd:dateTime'},
#     'interval': {'@id': 'owlTime:hasTime', '@container': '@list'}},
#    '@id': 'dct:time'},
#   'coordRefSys': 'http://www.opengis.net/def/glossary/term/CoordinateReferenceSystemCRS',
#   'place': 'dct:spatial',
#   'Polyhedron': 'geojson:Polyhedron',
#   'MultiPolyhedron': 'geojson:MultiPolyhedron',
#   'Prism': {'@id': 'geojson:Prism',
#    '@context': {'base': 'geojson:prismBase',
#     'lower': 'geojson:prismLower',
#     'upper': 'geojson:prismUpper'}},
#   'MultiPrism': {'@id': 'geojson:MultiPrism',
#    '@context': {'prisms': 'geojson:prisms'}},
#   'coordinates': {'@container': '@list', '@id': 'geojson:coordinates'},
#   'geometries': {'@id': 'geojson:geometry', '@container': '@list'},
#   'PhotonFluxDensity': 'http://purl.oclc.org/NET/ssnx/qu/dim#PhotonFluxDensity',
#   'invalidatedAtTime': {'@id': 'http://www.w3.org/ns/prov#invalidatedAtTime',
#    '@type': 'xsd:dateTime'},
#   'Attachable': 'http://purl.org/linked-data/cube#Attachable',
#   'QuantityValue': 'http://qudt.org/schema/qudt/QuantityValue',
#   'affiliation': 'https://schema.org/affiliation',
#   'Unit': 'http://qudt.org/schema/qudt/Unit',
#   'Line': 'http://www.opengis.net/ont/sf#Line',
#   'member': {'@id': 'http://xmlns.com/foaf/0.1/member', '@type': '@id'},
#   'versionInfo': 'http://www.w3.org/2002/07/owl#versionInfo',
#   'generatedAtTime': {'@id': 'http://www.w3.org/ns/prov#generatedAtTime',
#    '@type': 'xsd:dateTime'},
#   'example': 'http://www.w3.org/2004/02/skos/core#example',
#   'Slice': 'http://purl.org/linked-data/cube#Slice',
#   'Concentration': 'http://purl.oclc.org/NET/ssnx/qu/dim#Concentration',
#   'dataSet': {'@id': 'http://purl.org/linked-data/cube#dataSet',
#    '@type': '@id'},
#   'componentAttachment': {'@id': 'http://purl.org/linked-data/cube#componentAttachment',
#    '@type': '@id'},
#   'concept': {'@id': 'http://purl.org/linked-data/cube#concept',
#    '@type': '@id'},
#   'MultiSurface': 'http://www.opengis.net/ont/sf#MultiSurface',
#   'TemporalDuration': 'owlTime:TemporalDuration',
#   'Procedure': 'sosa:Procedure',
#   'DiffusionCoefficient': 'http://purl.oclc.org/NET/ssnx/qu/dim#DiffusionCoefficient',
#   'asGeoJSON': {'@id': 'http://www.opengis.net/ont/geosparql#asGeoJSON',
#    '@type': 'http://www.opengis.net/ont/geosparql#geoJSONLiteral'},
#   'Organization': 'https://schema.org/Organization',
#   'Volume': 'http://purl.oclc.org/NET/ssnx/qu/dim#Volume',
#   'Thing': 'http://www.w3.org/2002/07/owl#Thing',
#   'GFI_Feature': 'http://def.isotc211.org/iso19156/2011/GeneralFeatureInstance#GFI_Feature',
#   'AttributeProperty': 'http://purl.org/linked-data/cube#AttributeProperty',
#   'quantityValue': {'@id': 'http://qudt.org/schema/qudt/quantityValue',
#    '@type': '@id'},
#   'TemporalUnit': 'owlTime:TemporalUnit',
#   'asWKT': {'@id': 'http://www.opengis.net/ont/geosparql#asWKT',
#    '@type': 'http://www.opengis.net/ont/geosparql#wktLiteral'},
#   'Angle': 'http://purl.oclc.org/NET/ssnx/qu/dim#Angle',
#   'TemperatureDrift': 'http://purl.oclc.org/NET/ssnx/qu/dim#TemperatureDrift',
#   'RotationalSpeed': 'http://purl.oclc.org/NET/ssnx/qu/dim#RotationalSpeed',
#   'ComponentProperty': 'http://purl.org/linked-data/cube#ComponentProperty',
#   'Class': 'rdfs:Class',
#   'Geometry': 'http://www.opengis.net/ont/geosparql#Geometry',
#   'NumberPerArea': 'http://purl.oclc.org/NET/ssnx/qu/dim#NumberPerArea',
#   'depiction': 'http://xmlns.com/foaf/0.1/depiction',
#   'Curve': 'http://www.opengis.net/ont/sf#Curve',
#   'Instant': 'owlTime:Instant',
#   'maker': 'http://xmlns.com/foaf/0.1/maker',
#   'sfWithin': {'@id': 'http://www.opengis.net/ont/geosparql#sfWithin',
#    '@type': '@id'},
#   'ThermalConductivity': 'http://purl.oclc.org/NET/ssnx/qu/dim#ThermalConductivity',
#   'domainIncludes': 'https://schema.org/domainIncludes',
#   'long': 'http://www.w3.org/2003/01/geo/wgs84_pos#long',
#   'numericValue': 'http://qudt.org/schema/qudt/numericValue',
#   'Concept': 'http://www.w3.org/2004/02/skos/core#Concept',
#   'component': {'@id': 'http://purl.org/linked-data/cube#component',
#    '@type': '@id'},
#   'measure': {'@id': 'http://purl.org/linked-data/cube#measure',
#    '@type': '@id'},
#   'SliceKey': 'http://purl.org/linked-data/cube#SliceKey',
#   'Result': 'sosa:Result',
#   'Compressibility': 'http://purl.oclc.org/NET/ssnx/qu/dim#Compressibility',
#   'ComponentSet': 'http://purl.org/linked-data/cube#ComponentSet',
#   'MassPerTimePerArea': 'http://purl.oclc.org/NET/ssnx/qu/dim#MassPerTimePerArea',
#   'numericDuration': {'@id': 'owlTime:numericDuration',
#    '@type': 'xsd:decimal'},
#   'ElectricConductivity': 'http://purl.oclc.org/NET/ssnx/qu/dim#ElectricConductivity',
#   'Temperature': 'http://purl.oclc.org/NET/ssnx/qu/dim#Temperature',
#   'homepage': 'http://xmlns.com/foaf/0.1/homepage',
#   'Measure': 'http://def.seegrid.csiro.au/isotc211/iso19103/2005/basic#Measure',
#   'Person': 'http://xmlns.com/foaf/0.1/Person',
#   'Triangle': 'http://www.opengis.net/ont/sf#Triangle',
#   'note': 'http://www.w3.org/2004/02/skos/core#note',
#   'observationGroup': {'@id': 'http://purl.org/linked-data/cube#observationGroup',
#    '@type': '@id'},
#   'Interval': 'owlTime:Interval',
#   'EnergyFlux': 'http://purl.oclc.org/NET/ssnx/qu/dim#EnergyFlux',
#   'StressOrPressure': 'http://purl.oclc.org/NET/ssnx/qu/dim#StressOrPressure',
#   'VolumeDensityRate': 'http://purl.oclc.org/NET/ssnx/qu/dim#VolumeDensityRate',
#   'Agent': 'http://xmlns.com/foaf/0.1/Agent',
#   'creator': 'dct:creator',
#   'Energy': 'http://purl.oclc.org/NET/ssnx/qu/dim#Energy',
#   'foaf.name': 'http://xmlns.com/foaf/0.1/name',
#   'Role': 'https://schema.org/Role',
#   'hasSerialization': {'@id': 'http://www.opengis.net/ont/geosparql#hasSerialization',
#    '@type': 'rdfs:Literal'},
#   'hasTime': {'@id': 'owlTime:hasTime', '@type': '@id'},
#   'SF_SamplingFeature.sampledFeature': {'@id': 'http://def.isotc211.org/iso19156/2011/SamplingFeature#SF_SamplingFeature.sampledFeature',
#    '@type': '@id'},
#   'rangeIncludes': 'https://schema.org/rangeIncludes',
#   'Mass': 'http://purl.oclc.org/NET/ssnx/qu/dim#Mass',
#   'location': {'@id': 'http://www.w3.org/2003/01/geo/wgs84_pos#location',
#    '@type': '@id'},
#   'ComponentSpecification': 'http://purl.org/linked-data/cube#ComponentSpecification',
#   'Scheme': 'http://www.w3.org/2004/02/skos/core#Scheme',
#   'hasEnd': {'@id': 'owlTime:hasEnd', '@type': '@id'},
#   'rights': 'dct:rights',
#   'TemporalEntity': 'owlTime:TemporalEntity',
#   'hasBeginning': {'@id': 'owlTime:hasBeginning', '@type': '@id'},
#   'SF_SamplingFeature': 'http://def.isotc211.org/iso19156/2011/SamplingFeature#SF_SamplingFeature',
#   'DimensionProperty': 'http://purl.org/linked-data/cube#DimensionProperty',
#   'alt': 'http://www.w3.org/2003/01/geo/wgs84_pos#alt',
#   'Acceleration': 'http://purl.oclc.org/NET/ssnx/qu/dim#Acceleration',
#   'identifier': 'dct:identifier',
#   'Quantity': 'http://qudt.org/schema/qudt/Quantity',
#   'MassFlowRate': 'http://purl.oclc.org/NET/ssnx/qu/dim#MassFlowRate',
#   'qu.QuantityKind': 'http://purl.oclc.org/NET/ssnx/qu/qu#QuantityKind',
#   'SpatialObjectCollection': 'http://www.opengis.net/ont/geosparql#SpatialObjectCollection',
#   'Distance': 'http://purl.oclc.org/NET/ssnx/qu/dim#Distance',
#   'deprecated': 'http://www.w3.org/2002/07/owl#deprecated',
#   'Radiance': 'http://purl.oclc.org/NET/ssnx/qu/dim#Radiance',
#   'Duration': 'owlTime:Duration',
#   'TIN': 'http://www.opengis.net/ont/sf#TIN',
#   'SurfaceDensity': 'http://purl.oclc.org/NET/ssnx/qu/dim#SurfaceDensity',
#   'isDefinedBy': 'rdfs:isDefinedBy',
#   'wgs84.Point': 'http://www.w3.org/2003/01/geo/wgs84_pos#Point',
#   'definition': 'http://www.w3.org/2004/02/skos/core#definition',
#   'editorialNote': 'http://www.w3.org/2004/02/skos/core#editorialNote',
#   'order': {'@id': 'http://purl.org/linked-data/cube#order',
#    '@type': 'xsd:int'},
#   'hasGeometry': {'@id': 'http://www.opengis.net/ont/geosparql#hasGeometry',
#    '@type': '@id'},
#   'ssn.Property': 'ssn:Property',
#   'sfContains': {'@id': 'http://www.opengis.net/ont/geosparql#sfContains',
#    '@type': '@id'},
#   'title': 'dct:title',
#   'Density': 'http://purl.oclc.org/NET/ssnx/qu/dim#Density',
#   'LinearRing': 'http://www.opengis.net/ont/sf#LinearRing',
#   'Molality': 'http://purl.oclc.org/NET/ssnx/qu/dim#Molality',
#   'inXSDDateTimeStamp': {'@id': 'owlTime:inXSDDateTimeStamp',
#    '@type': 'xsd:dateTimeStamp'},
#   'MeasureProperty': 'http://purl.org/linked-data/cube#MeasureProperty',
#   'PropertyKind': 'http://purl.oclc.org/NET/ssnx/qu/qu#PropertyKind',
#   'SpatialObject': 'http://www.opengis.net/ont/geosparql#SpatialObject',
#   'sliceStructure': {'@id': 'http://purl.org/linked-data/cube#sliceStructure',
#    '@type': '@id'},
#   'NumberPerLength': 'http://purl.oclc.org/NET/ssnx/qu/dim#NumberPerLength',
#   'lat': 'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#   'VolumeFlowRate': 'http://purl.oclc.org/NET/ssnx/qu/dim#VolumeFlowRate',
#   'SpecificEntropy': 'http://purl.oclc.org/NET/ssnx/qu/dim#SpecificEntropy',
#   'CodedProperty': 'http://purl.org/linked-data/cube#CodedProperty',
#   'slice': {'@id': 'http://purl.org/linked-data/cube#slice', '@type': '@id'},
#   'unit': {'@id': 'http://qudt.org/schema/qudt/unit', '@type': '@id'},
#   'date': 'dct:date',
#   'seeAlso': 'rdfs:seeAlso',
#   'ObservationGroup': 'http://purl.org/linked-data/cube#ObservationGroup',
#   'DataSet': 'http://purl.org/linked-data/cube#DataSet',
#   'comment': 'rdfs:comment',
#   'PolyhedralSurface': 'http://www.opengis.net/ont/sf#PolyhedralSurface',
#   'contributor': 'dct:contributor',
#   'unitKind': {'@id': 'http://purl.oclc.org/NET/ssnx/qu/qu#unitKind',
#    '@type': '@id'},
#   'dimension': {'@id': 'http://purl.org/linked-data/cube#dimension',
#    '@type': '@id'},
#   'RadianceExposure': 'http://purl.oclc.org/NET/ssnx/qu/dim#RadianceExposure',
#   'VelocityOrSpeed': 'http://purl.oclc.org/NET/ssnx/qu/dim#VelocityOrSpeed',
#   'inXSDDate': {'@id': 'owlTime:inXSDDate', '@type': 'xsd:date'},
#   'GFI_DomainFeature': 'http://def.isotc211.org/iso19156/2011/GeneralFeatureInstance#GFI_DomainFeature',
#   'observation': {'@id': 'http://purl.org/linked-data/cube#observation',
#    '@type': '@id'},
#   'Dimensionless': 'http://purl.oclc.org/NET/ssnx/qu/dim#Dimensionless',
#   'Area': 'http://purl.oclc.org/NET/ssnx/qu/dim#Area',
#   'Power': 'http://purl.oclc.org/NET/ssnx/qu/dim#Power',
#   'OM_Observation': 'http://def.isotc211.org/iso19156/2011/Observation#OM_Observation',
#   'prefLabel': 'http://www.w3.org/2004/02/skos/core#prefLabel',
#   'Surface': 'http://www.opengis.net/ont/sf#Surface',
#   'sliceKey': {'@id': 'http://purl.org/linked-data/cube#sliceKey',
#    '@type': '@id'},
#   'inScheme': 'http://www.w3.org/2004/02/skos/core#inScheme',
#   'dct.description': 'dct:description',
#   'MultiCurve': 'http://www.opengis.net/ont/sf#MultiCurve',
#   'hasQuantityKind': {'@id': 'http://qudt.org/schema/qudt/hasQuantityKind',
#    '@type': '@id'},
#   'DataStructureDefinition': 'http://purl.org/linked-data/cube#DataStructureDefinition',
#   'qb.Observation': 'http://purl.org/linked-data/cube#Observation',
#   'EnergyDensity': 'http://purl.oclc.org/NET/ssnx/qu/dim#EnergyDensity',
#   'unitType': {'@id': 'owlTime:unitType', '@type': '@id'},
#   'componentProperty': {'@id': 'http://purl.org/linked-data/cube#componentProperty',
#    '@type': '@id'},
#   'sf.Geometry': 'http://www.opengis.net/ont/sf#Geometry',
#   'schema.Person': 'https://schema.org/Person',
#   'schema.name': 'https://schema.org/name',
#   'QuantityKind': 'http://qudt.org/schema/qudt/QuantityKind',
#   'sosa': 'http://www.w3.org/ns/sosa/',
#   'ssn-system': 'ssn:systems/',
#   'ssn': 'http://www.w3.org/ns/ssn/',
#   'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#   'iliad': 'https://w3id.org/iliad/property/',
#   'jf-property': 'https://w3id.org/iliad/jellyfish/property/',
#   'jf-density': 'jf-property:densityOfJF/',
#   'geojson': 'https://purl.org/geojson/vocab#',
#   'oa': 'http://www.w3.org/ns/oa#',
#   'dct': 'http://purl.org/dc/terms/',
#   'owlTime': 'http://www.w3.org/2006/time#',
#   'xsd': 'http://www.w3.org/2001/XMLSchema#',
#   '@version': 1.1}}

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, RDFS, XSD

def json_to_rdf(data):
    data_with_context = {
    "@context": context["@context"],
    "@graph": data
    }
    # Convert JSON-LD to RDF
    g = Graph()
    g.parse(data=json.dumps(data_with_context), format='json-ld')

    # Print the RDF data
    g_ttl = g.serialize(format='turtle')
    return g_ttl, g

g_ttl, g = json_to_rdf(data)
print(g_ttl)
# Out:
# @prefix geojson: <https://purl.org/geojson/vocab#> .
# @prefix iliad: <https://w3id.org/iliad/property/> .
# @prefix jf-density: <https://w3id.org/iliad/jellyfish/property/densityOfJF/> .
# @prefix jf-property: <https://w3id.org/iliad/jellyfish/property/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sosa: <http://www.w3.org/ns/sosa/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://w3id.org/iliad/jellyfish/observation/1-18-527-Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     rdfs:label "Jelly fish observation #1 location id: 18 sensor: 527 species: Phyllorhiza punctata"@en ;
#     sosa:hasFeatureOfInterest <https://w3id.org/iliad/jellyfish/feature/1-18> ;
#     sosa:hasResult [ jf-property:beachedJF "1" ;
#             jf-property:densityOfJF jf-density:Some ;
#             jf-property:quantityOfJF 50 ;
#             jf-property:stingByJF "Unspecified" ;
#             iliad:sampleSizeValue "10-30" ;
#             iliad:speciesScientificName "Phyllorhiza punctata" ;
#             iliad:wormsConcept <https://marinespecies.org/aphia.php?p=taxdetails&id=135298> ] ;
#     sosa:observedProperty jf-property:jellyFishAbundanceProperty ;
#     sosa:phenomenonTime <https://w3id.org/iliad/jellyfish/observation/2011-07-01T09:00:00> ;
#     sosa:resultTime "2011-07-01T09:00:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.463478e+01 3.180691e+01 ) ] .

# %%
# Define the SPARQL query to filter out specific types of observations
query = """
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX jf-property: <https://w3id.org/iliad/jellyfish/property/>
PREFIX geojson: <https://purl.org/geojson/vocab#>
PREFIX iliad: <https://w3id.org/iliad/property/>

SELECT ?observation ?quantity ?coordinates ?species ?latitude ?longitude
WHERE {
# ?observation a sosa:Observation ;
    sosa:hasResult ?result ;
    geojson:geometry ?geometry ;
    sosa:observedProperty jf-property:jellyFishAbundanceProperty .
# ?result jf-property:quantityOfJF ?quantity ;
    jf-property:densityOfJF ?density ;
    iliad:speciesScientificName ?species .
# ?geometry geojson:coordinates ?coordinates .
# ?coordinates rdf:first ?latitude ;
        rdf:rest/rdf:first ?longitude .
}
"""

# Execute the SPARQL query on the RDF graph
results = g.query(query)

# Process and print the results
output = ""
for result in results:
    observation = result["observation"]
    quantity = result["quantity"]
    coordinates = result["coordinates"]
    latitude = result["latitude"]
    longitude = result["longitude"]
    species = result["species"]
    output = output + f"Observation: {observation}, Quantity: {quantity}, Coordinates: {latitude} {longitude}, Species: {species}"

output
# Out:
# 'Observation: https://w3id.org/iliad/jellyfish/observation/1-18-527-Phyllorhiza_punctata, Quantity: 50, Coordinates: 34.634776 31.80691, Species: Phyllorhiza punctata'

# %%
# Process and print the results
output = ""
for result in results:
    observation = result["observation"]
    quantity = result["quantity"]
    coordinates = result["coordinates"]
    output = output + "\n" + f"Observation: {observation}, Quantity: {quantity}, Coordinates: {coordinates}"

output
# Out:
# '\nObservation: https://w3id.org/iliad/jellyfish/observation/1-18-527-Phyllorhiza_punctata, Quantity: 50, Coordinates: N4f319667f28a4384ba7506c19657549b'

# %% [markdown]
# # now query your own endpoint
# In the following examples, client application will query data from custom endpoin exposing standardised API, context definition in these cases is also external

# %%
url = "http://localhost:5002/collections/my-observations-schema.org/items?f=json"
#we'll keep data in as object for some experiments
data2 = requests.get(url).json()

# %%
#We're using previously defined function to put on the map in the same style but different data
#Mind, that data is in the standards format comlioent with GeoJSON, OGC API Features, OGC API EDR Items, OGC API Records. Each of these shall behave similarily
map_features(data2,[31.80691, 34.634776],8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04e8127fd752fa682b976380116e82ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04e8127fd752fa682b976380116e82ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04e8127fd752fa682b976380116e82ab = L.map(
#                 &quot;map_04e8127fd752fa682b976380116e82ab&quot;,
#                 {
#                     center: [31.80691, 34.634776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5900df8b821115ddf0e47354630628e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5900df8b821115ddf0e47354630628e7.addTo(map_04e8127fd752fa682b976380116e82ab);
#
#
#
#         function geo_json_8b04f735fe0d77da8f0522c8d8b5c986_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8b04f735fe0d77da8f0522c8d8b5c986 = L.geoJson(null, {
#                 onEachFeature: geo_json_8b04f735fe0d77da8f0522c8d8b5c986_onEachFeature,
#
#         });
#
#         function geo_json_8b04f735fe0d77da8f0522c8d8b5c986_add (data) {
#             geo_json_8b04f735fe0d77da8f0522c8d8b5c986
#                 .addData(data);
#         }
#             geo_json_8b04f735fe0d77da8f0522c8d8b5c986_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [34.790955, 32.355448], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast340725.416666666730-60Rhopilema nomadica&quot;, &quot;properties&quot;: {&quot;Distance_from_coast&quot;: &quot;1000-10000&quot;, &quot;Location_20_Zones_ID&quot;: 10, &quot;MachineObservation&quot;: &quot;-&quot;, &quot;Quantity_Reported&quot;: 50, &quot;Stinging_Water&quot;: &quot;Unspecified&quot;, &quot;basisOfRecord&quot;: &quot;HumanObservation&quot;, &quot;coordinateUncertaintyInMeters&quot;: 10000, &quot;date&quot;: &quot;01/07/2011&quot;, &quot;dateFix&quot;: &quot;07/01/2011&quot;, &quot;decimalLatitude_ori&quot;: &quot;32,355,448&quot;, &quot;decimalLongitude_ori&quot;: &quot;34,790,955&quot;, &quot;distanceWalkedinmeters&quot;: &quot;-&quot;, &quot;eventDate&quot;: &quot;2011-07-01T10:00:00&quot;, &quot;eventDate_ori&quot;: &quot;01/07/2011 10:00&quot;, &quot;eventType&quot;: 0, &quot;goldUser&quot;: 1, &quot;obsID&quot;: 3, &quot;occurrence&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast&quot;, &quot;occurrenceStatus&quot;: &quot;present&quot;, &quot;organismQuantity&quot;: &quot;Swarm&quot;, &quot;organismQuantityType&quot;: &quot;Individuals&quot;, &quot;quantificationMethod&quot;: &quot;Fishing&quot;, &quot;recordedBy&quot;: 361, &quot;sampleSizeUnit&quot;: &quot;cm&quot;, &quot;sampleSizeValue&quot;: &quot;30-60&quot;, &quot;scientificName&quot;: &quot;Rhopilema nomadica&quot;, &quot;scientificNameID&quot;: &quot;https://marinespecies.org/aphia.php?p=taxdetails\u0026id=232032&quot;, &quot;strandedJellyfish&quot;: 1, &quot;time&quot;: &quot;10:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [34.790955, 32.355448], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Rhizostoma pulmo&quot;, &quot;properties&quot;: {&quot;Distance_from_coast&quot;: &quot;1000-10000&quot;, &quot;Location_20_Zones_ID&quot;: 10, &quot;MachineObservation&quot;: &quot;-&quot;, &quot;Quantity_Reported&quot;: 50, &quot;Stinging_Water&quot;: &quot;Unspecified&quot;, &quot;basisOfRecord&quot;: &quot;HumanObservation&quot;, &quot;coordinateUncertaintyInMeters&quot;: 10000, &quot;date&quot;: &quot;01/07/2011&quot;, &quot;dateFix&quot;: &quot;07/01/2011&quot;, &quot;decimalLatitude_ori&quot;: &quot;32,355,448&quot;, &quot;decimalLongitude_ori&quot;: &quot;34,790,955&quot;, &quot;distanceWalkedinmeters&quot;: &quot;-&quot;, &quot;eventDate&quot;: &quot;2011-07-01T10:00:00&quot;, &quot;eventDate_ori&quot;: &quot;01/07/2011 10:00&quot;, &quot;eventType&quot;: 0, &quot;goldUser&quot;: 1, &quot;obsID&quot;: 3, &quot;occurrence&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast&quot;, &quot;occurrenceStatus&quot;: &quot;present&quot;, &quot;organismQuantity&quot;: &quot;Swarm&quot;, &quot;organismQuantityType&quot;: &quot;Individuals&quot;, &quot;quantificationMethod&quot;: &quot;Fishing&quot;, &quot;recordedBy&quot;: 361, &quot;sampleSizeUnit&quot;: &quot;cm&quot;, &quot;sampleSizeValue&quot;: &quot;0-10&quot;, &quot;scientificName&quot;: &quot;Rhizostoma pulmo&quot;, &quot;scientificNameID&quot;: &quot;http://marinespecies.org/aphia.php?p=taxdetails\u0026id=135299&quot;, &quot;strandedJellyfish&quot;: 1, &quot;time&quot;: &quot;10:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [34.790955, 32.355448], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Jellyfish_in_

# %%
# !pip install pyshacl
# Out:
# Requirement already satisfied: pyshacl in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (0.29.0)
# Requirement already satisfied: importlib-metadata>6 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pyshacl) (8.5.0)
# Requirement already satisfied: owlrl<8,>=7.1.2 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pyshacl) (7.1.2)
# Requirement already satisfied: packaging>=21.3 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pyshacl) (24.1)
# Requirement already satisfied: prettytable>=3.5.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from pyshacl) (3.12.0)
# Requirement already satisfied: rdflib<8.0,>=7.1.1 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rdflib[html]<8.0,>=7.1.1->pyshacl) (7.1.1)
# Requirement already satisfied: zipp>=3.20 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from importlib-metadata>6->pyshacl) (3.20.2)
# Requirement already satisfied: wcwidth in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from prettytable>=3.5.0->pyshacl) (0.2.13)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rdflib<8.0,>=7.1.1->rdflib[html]<8.0,>=7.1.1->pyshacl) (3.1.4)
# Requirement already satisfied: html5rdf<2,>=1.2 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rdflib[html]<8.0,>=7.1.1->pyshacl) (1.2.1)

# %%
import pyshacl

data3=requests.get('http://localhost:5002/collections/my-observations-schema.org/items?f=json&offset=1&limit=1').json()

shacl_rules_url = 'https://opengeospatial.github.io/ogcapi-sosa/_sources/features/observation/semantic-uplift/featureType.shacl'

shacl_graph = Graph().parse(shacl_rules_url, format='ttl')

json_ld_data = json.dumps({**context, **data3}, indent=2)

print(json_ld_data)

data_graph = Graph().parse(data=json_ld_data, format='json-ld', base=url)
pyshacl.validate(data_graph, shacl_graph, advanced=True, in_place=True)

print(data_graph.serialize(format='ttl'))
# Out:
# {
#   "@context": {
#     "@base": "https://w3id.org/iliad/jellyfish/observation/",
#     "resultTime": "sosa:resultTime",
#     "phenomenonTime": {
#       "@id": "sosa:phenomenonTime",
#       "@type": "@id"
#     },
#     "hasFeatureOfInterest": {
#       "@context": {
#         "@base": "https://w3id.org/iliad/jellyfish/feature/"
#       },
#       "@id": "sosa:hasFeatureOfInterest",
#       "@type": "@id"
#     },
#     "observedProperty": {
#       "@context": {
#         "@base": "https://w3id.org/iliad/jellyfish/property/"
#       },
#       "@id": "sosa:observedProperty",
#       "@type": "@id"
#     },
#     "usedProcedure": {
#       "@id": "sosa:usedProcedure",
#       "@type": "@id"
#     },
#     "madeBySensor": {
#       "@id": "sosa:madeBySensor",
#       "@type": "@id"
#     },
#     "id": "@id",
#     "properties": "@nest",
#     "featureType": "@type",
#     "ActuatableProperty": {
#       "@id": "sosa:ActuatableProperty",
#       "@type": "@id"
#     },
#     "Actuation": {
#       "@id": "sosa:Actuation",
#       "@type": "@id"
#     },
#     "ActuationCollection": {
#       "@id": "sosa:ActuationCollection",
#       "@type": "@id"
#     },
#     "Actuator": {
#       "@id": "sosa:Actuator",
#       "@type": "@id"
#     },
#     "Deployment": {
#       "@id": "sosa:Deployment",
#       "@type": "@id"
#     },
#     "Execution": {
#       "@id": "sosa:Execution",
#       "@type": "@id"
#     },
#     "FeatureOfInterest": {
#       "@id": "sosa:FeatureOfInterest",
#       "@type": "@id"
#     },
#     "ObservableProperty": {
#       "@id": "sosa:ObservableProperty",
#       "@type": "@id"
#     },
#     "Observation": {
#       "@id": "sosa:Observation",
#       "@type": "@id"
#     },
#     "ObservationCollection": {
#       "@id": "sosa:ObservationCollection",
#       "@type": "@id"
#     },
#     "Platform": {
#       "@id": "sosa:Platform",
#       "@type": "@id"
#     },
#     "Property": {
#       "@id": "sosa:Property",
#       "@type": "@id"
#     },
#     "Procedure ": {
#       "@id": "sosa:Procedure",
#       "@type": "@id"
#     },
#     "Sample": {
#       "@id": "sosa:Sample",
#       "@type": "@id"
#     },
#     "SampleCollection": {
#       "@id": "sosa:SampleCollection",
#       "@type": "@id"
#     },
#     "Sampler": {
#       "@id": "sosa:Sampler",
#       "@type": "@id"
#     },
#     "Sampling": {
#       "@id": "sosa:Sampling",
#       "@type": "@id"
#     },
#     "Sensor": {
#       "@id": "sosa:Sensor",
#       "@type": "@id"
#     },
#     "Stimulus": {
#       "@id": "sosa:Stimulus",
#       "@type": "@id"
#     },
#     "System": {
#       "@id": "sosa:System",
#       "@type": "@id"
#     },
#     "actsOnProperty": {
#       "@id": "sosa:actsOnProperty",
#       "@type": "@id"
#     },
#     "deployedOnPlatform": {
#       "@id": "sosa:deployedOnPlatform",
#       "@type": "@id"
#     },
#     "deployedSystem": {
#       "@id": "sosa:deployedSystem",
#       "@type": "@id"
#     },
#     "detects": {
#       "@id": "sosa:detects",
#       "@type": "@id"
#     },
#     "features": {
#       "@id": "sosa:hasMember",
#       "@type": "@id",
#       "@container": "@set",
#       "@context": {
#         "hasFeatureOfInterest": {
#           "@id": "sosa:hasFeatureOfInterest",
#           "@type": "@id"
#         },
#         "hasResult": {
#           "@id": "sosa:hasResult",
#           "@type": "@id"
#         }
#       }
#     },
#     "forProperty": {
#       "@id": "sosa:forProperty",
#       "@type": "@id"
#     },
#     "hasDeployment": {
#       "@id": "sosa:hasDeployment",
#       "@type": "@id"
#     },
#     "hasInput": {
#       "@id": "sosa:hasInput",
#       "@type": "@id"
#     },
#     "hasMember": {
#       "@id": "sosa:hasMember",
#       "@type": "@id",
#       "@context": {
#         "hasFeatureOfInterest": {
#           "@id": "sosa:hasFeatureOfInterest",
#           "@type": "@id"
#         },
#         "hasResult": {
#           "@id": "sosa:hasResult",
#           "@type": "@id"
#         }
#       }
#     },
#     "hasOriginalSample": {
#       "@id": "sosa:hasOriginalSample",
#       "@type": "@id"
#     },
#     "hasOutput": {
#       "@id": "sosa:hasOutput",
#       "@type": "@id"
#     },
#     "hasProperty": {
#       "@id": "sosa:hasProperty",
#       "@type": "@id"
#     },
#     "hasResult": {
#       "@id": "sosa:hasResult",
#       "@type": "@id",
#       "@context": {
#         "quantityOfJF": "jf-property:quantityOfJF",
#         "densityOfJF": {
#           "@context": {
#             "@base": "https://w3id.org/iliad/jellyfish/property/densityOfJF/"
#           },
#           "@id": "jf-property:densityOfJF",
#           "@type": "@id"
#         },
#         "stingByJF": "jf-property:stingByJF",
#         "beachedJF": "jf-property:beachedJF"
#       }
#     },
#     "hasResultQuality": {
#       "@id": "sosa:hasResultQuality",
#       "@type": "@id"
#     },
#     "hasSample": {
#       "@id": "sosa:hasSample",
#       "@type": "@id"
#     },
#     "hasSampledFeature": {
#       "@id": "sosa:hasSampledFeature",
#       "@type": "@id"
#     },
#     "hasSimpleResult": {
#       "@id": "sosa:hasSimpleResult",
#       "@type": "@id"
#     },
#     "hasSubSystem": {
#       "@id": "sosa:hasSubSystem",
#       "@type": "@id",
#       "@container": "@set"
#     },
#     "hasUltimateFeatureOfInterest": {
#       "@id": "sosa:hasUltimateFeatureOfInterest",
#       "@type": "@id"
#     },
#     "hosts": {
#       "@id": "sosa:hosts",
#       "@type": "@id",
#       "@container": "@set"
#     },
#     "implementedBy": {
#       "@id": "sosa:implementedBy",
#       "@type": "@id"
#     },
#     "implements": {
#       "@id": "sosa:implements",
#       "@type": "@id"
#     },
#     "inDeployment": {
#       "@id": "sosa:inDeployment",
#       "@type": "@id"
#     },
#     "isActedOnBy": {
#       "@id": "sosa:isActedOnBy",
#       "@type": "@id"
#     },
#     "isFeatureOfInterestOf": {
#       "@id": "sosa:isFeatureOfInterestOf",
#       "@type": "@id"
#     },
#     "isHostedBy": {
#       "@id": "sosa:isHostedBy",
#       "@type": "@id"
#     },
#     "isObservedBy": {
#       "@id": "sosa:isObservedBy",
#       "@type": "@id"
#     },
#     "isPropertyOf": {
#       "@id": "sosa:isPropertyOf",
#       "@type": "@id"
#     },
#     "isProxyFor": {
#       "@id": "sosa:isProxyFor",
#       "@type": "@id"
#     },
#     "isResultOf": {
#       "@id": "sosa:isResultOf",
#       "@type": "@id"
#     },
#     "isResultOfMadeBySampler": {
#       "@id": "sosa:isResultOfMadeBySampler",
#       "@type": "@id"
#     },
#     "isResultOfUsedProcedure": {
#       "@id": "sosa:isResultOfUsedProcedure",
#       "@type": "@id"
#     },
#     "isSampleOf": {
#       "@id": "sosa:isSampleOf",
#       "@type": "@id"
#     },
#     "madeActuation": {
#       "@id": "sosa:madeActuation",
#       "@type": "@id"
#     },
#     "madeByActuator": {
#       "@id": "sosa:madeByActuator",
#       "@type": "@id"
#     },
#     "madeBySampler": {
#       "@id": "sosa:madeBySampler",
#       "@type": "@id"
#     },
#     "madeObservation": {
#       "@id": "sosa:madeObservation",
#       "@type": "@id"
#     },
#     "madeSampling": {
#       "@id": "sosa:madeSampling",
#       "@type": "@id"
#     },
#     "observes": {
#       "@id": "sosa:observes",
#       "@type": "@id"
#     },
#     "wasOriginatedBy": {
#       "@id": "sosa:wasOriginatedBy",
#       "@type": "@id"
#     },
#     "Accuracy": {
#       "@id": "ssn-system:Accuracy",
#       "@type": "@id"
#     },
#     "ActuationRange": {
#       "@id": "ssn-system:ActuationRange",
#       "@type": "@id"
#     },
#     "BatteryLifetime": {
#       "@id": "ssn-system:BatteryLifetime",
#       "@type": "@id"
#     },
#     "DetectionLimit": {
#       "@id": "ssn-system:DetectionLimit",
#       "@type": "@id"
#     },
#     "Drift": {
#       "@id": "ssn-system:Drift",
#       "@type": "@id"
#     },
#     "Frequency": {
#       "@id": "ssn-system:Frequency",
#       "@type": "@id"
#     },
#     "Latency": {
#       "@id": "ssn-system:Latency",
#       "@type": "@id"
#     },
#     "MaintenanceSchedule": {
#       "@id": "ssn-system:MaintenanceSchedule",
#       "@type": "@id"
#     },
#     "MeasurementRange": {
#       "@id": "ssn-system:MeasurementRange",
#       "@type": "@id"
#     },
#     "OperatingPowerRange": {
#       "@id": "ssn-system:OperatingPowerRange",
#       "@type": "@id"
#     },
#     "OperatingProperty": {
#       "@id": "ssn-system:OperatingProperty",
#       "@type": "@id"
#     },
#     "OperatingRange": {
#       "@id": "ssn-system:OperatingRange",
#       "@type": "@id"
#     },
#     "Precision": {
#       "@id": "ssn-system:Precision",
#       "@type": "@id"
#     },
#     "Resolution": {
#       "@id": "ssn-system:Resolution",
#       "@type": "@id"
#     },
#     "ResponseTime": {
#       "@id": "ssn-system:ResponseTime",
#       "@type": "@id"
#     },
#     "Selectivity": {
#       "@id": "ssn-system:Selectivity",
#       "@type": "@id"
#     },
#     "Sensitivity": {
#       "@id": "ssn-system:Sensitivity",
#       "@type": "@id"
#     },
#     "SurvivalProperty": {
#       "@id": "ssn-system:SurvivalProperty",
#       "@type": "@id"
#     },
#     "SystemLifetime": {
#       "@id": "ssn-system:SystemLifetime",
#       "@type": "@id"
#     },
#     "SurvivalRange": {
#       "@id": "ssn-system:SurvivalRange",
#       "@type": "@id"
#     },
#     "SystemCapability": {
#       "@id": "ssn-system:SystemCapability",
#       "@type": "@id"
#     },
#     "SystemProperty": {
#       "@id": "ssn-system:SystemProperty",
#       "@type": "@id"
#     },
#     "hasOperatingProperty": {
#       "@id": "ssn-system:hasOperatingProperty",
#       "@type": "@id"
#     },
#     "hasOperatingRange": {
#       "@id": "ssn-system:hasOperatingRange",
#       "@type": "@id"
#     },
#     "hasSurvivalProperty": {
#       "@id": "ssn-system:hasSurvivalProperty",
#       "@type": "@id"
#     },
#     "hasSystemCapability": {
#       "@id": "ssn-system:hasSystemCapability",
#       "@type": "@id"
#     },
#     "hasSystemProperty": {
#       "@id": "ssn-system:hasSystemProperty",
#       "@type": "@id"
#     },
#     "hasSurvivalRange": {
#       "@id": "ssn-system:hasSurvivalRange",
#       "@type": "@id"
#     },
#     "inCondition": {
#       "@id": "ssn-system:inCondition",
#       "@type": "@id"
#     },
#     "qualityOfObservation": {
#       "@id": "ssn-system:qualityOfObservation",
#       "@type": "@id"
#     },
#     "label": {
#       "@id": "rdfs:label",
#       "@container": "@language"
#     },
#     "sampleSizeValue": "iliad:sampleSizeValue",
#     "speciesScientificName": "iliad:speciesScientificName",
#     "wormsConcept": {
#       "@id": "iliad:wormsConcept",
#       "@type": "@id"
#     },
#     "type": "@type",
#     "geometry": "geojson:geometry",
#     "bbox": {
#       "@container": "@list",
#       "@id": "geojson:bbox"
#     },
#     "Feature": "geojson:Feature",
#     "FeatureCollection": "geojson:FeatureCollection",
#     "GeometryCollection": "geojson:GeometryCollection",
#     "LineString": "geojson:LineString",
#     "MultiLineString": "geojson:MultiLineString",
#     "MultiPoint": "geojson:MultiPoint",
#     "MultiPolygon": "geojson:MultiPolygon",
#     "Point": "geojson:Point",
#     "Polygon": "geojson:Polygon",
#     "links": {
#       "@context": {
#         "href": {
#           "@type": "@id",
#           "@id": "oa:hasTarget"
#         },
#         "rel": {
#           "@context": {
#             "@base": "http://www.iana.org/assignments/relation/"
#           },
#           "@id": "http://www.iana.org/assignments/relation",
#           "@type": "@id"
#         },
#         "type": "dct:type",
#         "hreflang": "dct:language",
#         "title": "rdfs:label",
#         "length": "dct:extent"
#       },
#       "@id": "rdfs:seeAlso"
#     },
#     "time": {
#       "@context": {
#         "date": {
#           "@id": "owlTime:hasTime",
#           "@type": "xsd:date"
#         },
#         "timestamp": {
#           "@id": "owlTime:hasTime",
#           "@type": "xsd:dateTime"
#         },
#         "interval": {
#           "@id": "owlTime:hasTime",
#           "@container": "@list"
#         }
#       },
#       "@id": "dct:time"
#     },
#     "coordRefSys": "http://www.opengis.net/def/glossary/term/CoordinateReferenceSystemCRS",
#     "place": "dct:spatial",
#     "Polyhedron": "geojson:Polyhedron",
#     "MultiPolyhedron": "geojson:MultiPolyhedron",
#     "Prism": {
#       "@id": "geojson:Prism",
#       "@context": {
#         "base": "geojson:prismBase",
#         "lower": "geojson:prismLower",
#         "upper": "geojson:prismUpper"
#       }
#     },
#     "MultiPrism": {
#       "@id": "geojson:MultiPrism",
#       "@context": {
#         "prisms": "geojson:prisms"
#       }
#     },
#     "coordinates": {
#       "@container": "@list",
#       "@id": "geojson:coordinates"
#     },
#     "geometries": {
#       "@id": "geojson:geometry",
#       "@container": "@list"
#     },
#     "PhotonFluxDensity": "http://purl.oclc.org/NET/ssnx/qu/dim#PhotonFluxDensity",
#     "invalidatedAtTime": {
#       "@id": "http://www.w3.org/ns/prov#invalidatedAtTime",
#       "@type": "xsd:dateTime"
#     },
#     "Attachable": "http://purl.org/linked-data/cube#Attachable",
#     "QuantityValue": "http://qudt.org/schema/qudt/QuantityValue",
#     "affiliation": "https://schema.org/affiliation",
#     "Unit": "http://qudt.org/schema/qudt/Unit",
#     "Line": "http://www.opengis.net/ont/sf#Line",
#     "member": {
#       "@id": "http://xmlns.com/foaf/0.1/member",
#       "@type": "@id"
#     },
#     "versionInfo": "http://www.w3.org/2002/07/owl#versionInfo",
#     "generatedAtTime": {
#       "@id": "http://www.w3.org/ns/prov#generatedAtTime",
#       "@type": "xsd:dateTime"
#     },
#     "example": "http://www.w3.org/2004/02/skos/core#example",
#     "Slice": "http://purl.org/linked-data/cube#Slice",
#     "Concentration": "http://purl.oclc.org/NET/ssnx/qu/dim#Concentration",
#     "dataSet": {
#       "@id": "http://purl.org/linked-data/cube#dataSet",
#       "@type": "@id"
#     },
#     "componentAttachment": {
#       "@id": "http://purl.org/linked-data/cube#componentAttachment",
#       "@type": "@id"
#     },
#     "concept": {
#       "@id": "http://purl.org/linked-data/cube#concept",
#       "@type": "@id"
#     },
#     "MultiSurface": "http://www.opengis.net/ont/sf#MultiSurface",
#     "TemporalDuration": "owlTime:TemporalDuration",
#     "Procedure": "sosa:Procedure",
#     "DiffusionCoefficient": "http://purl.oclc.org/NET/ssnx/qu/dim#DiffusionCoefficient",
#     "asGeoJSON": {
#       "@id": "http://www.opengis.net/ont/geosparql#asGeoJSON",
#       "@type": "http://www.opengis.net/ont/geosparql#geoJSONLiteral"
#     },
#     "Organization": "https://schema.org/Organization",
#     "Volume": "http://purl.oclc.org/NET/ssnx/qu/dim#Volume",
#     "Thing": "http://www.w3.org/2002/07/owl#Thing",
#     "GFI_Feature": "http://def.isotc211.org/iso19156/2011/GeneralFeatureInstance#GFI_Feature",
#     "AttributeProperty": "http://purl.org/linked-data/cube#AttributeProperty",
#     "quantityValue": {
#       "@id": "http://qudt.org/schema/qudt/quantityValue",
#       "@type": "@id"
#     },
#     "TemporalUnit": "owlTime:TemporalUnit",
#     "asWKT": {
#       "@id": "http://www.opengis.net/ont/geosparql#asWKT",
#       "@type": "http://www.opengis.net/ont/geosparql#wktLiteral"
#     },
#     "Angle": "http://purl.oclc.org/NET/ssnx/qu/dim#Angle",
#     "TemperatureDrift": "http://purl.oclc.org/NET/ssnx/qu/dim#TemperatureDrift",
#     "RotationalSpeed": "http://purl.oclc.org/NET/ssnx/qu/dim#RotationalSpeed",
#     "ComponentProperty": "http://purl.org/linked-data/cube#ComponentProperty",
#     "Class": "rdfs:Class",
#     "Geometry": "http://www.opengis.net/ont/geosparql#Geometry",
#     "NumberPerArea": "http://purl.oclc.org/NET/ssnx/qu/dim#NumberPerArea",
#     "depiction": "http://xmlns.com/foaf/0.1/depiction",
#     "Curve": "http://www.opengis.net/ont/sf#Curve",
#     "Instant": "owlTime:Instant",
#     "maker": "http://xmlns.com/foaf/0.1/maker",
#     "sfWithin": {
#       "@id": "http://www.opengis.net/ont/geosparql#sfWithin",
#       "@type": "@id"
#     },
#     "ThermalConductivity": "http://purl.oclc.org/NET/ssnx/qu/dim#ThermalConductivity",
#     "domainIncludes": "https://schema.org/domainIncludes",
#     "long": "http://www.w3.org/2003/01/geo/wgs84_pos#long",
#     "numericValue": "http://qudt.org/schema/qudt/numericValue",
#     "Concept": "http://www.w3.org/2004/02/skos/core#Concept",
#     "component": {
#       "@id": "http://purl.org/linked-data/cube#component",
#       "@type": "@id"
#     },
#     "measure": {
#       "@id": "http://purl.org/linked-data/cube#measure",
#       "@type": "@id"
#     },
#     "SliceKey": "http://purl.org/linked-data/cube#SliceKey",
#     "Result": "sosa:Result",
#     "Compressibility": "http://purl.oclc.org/NET/ssnx/qu/dim#Compressibility",
#     "ComponentSet": "http://purl.org/linked-data/cube#ComponentSet",
#     "MassPerTimePerArea": "http://purl.oclc.org/NET/ssnx/qu/dim#MassPerTimePerArea",
#     "numericDuration": {
#       "@id": "owlTime:numericDuration",
#       "@type": "xsd:decimal"
#     },
#     "ElectricConductivity": "http://purl.oclc.org/NET/ssnx/qu/dim#ElectricConductivity",
#     "Temperature": "http://purl.oclc.org/NET/ssnx/qu/dim#Temperature",
#     "homepage": "http://xmlns.com/foaf/0.1/homepage",
#     "Measure": "http://def.seegrid.csiro.au/isotc211/iso19103/2005/basic#Measure",
#     "Person": "http://xmlns.com/foaf/0.1/Person",
#     "Triangle": "http://www.opengis.net/ont/sf#Triangle",
#     "note": "http://www.w3.org/2004/02/skos/core#note",
#     "observationGroup": {
#       "@id": "http://purl.org/linked-data/cube#observationGroup",
#       "@type": "@id"
#     },
#     "Interval": "owlTime:Interval",
#     "EnergyFlux": "http://purl.oclc.org/NET/ssnx/qu/dim#EnergyFlux",
#     "StressOrPressure": "http://purl.oclc.org/NET/ssnx/qu/dim#StressOrPressure",
#     "VolumeDensityRate": "http://purl.oclc.org/NET/ssnx/qu/dim#VolumeDensityRate",
#     "Agent": "http://xmlns.com/foaf/0.1/Agent",
#     "creator": "dct:creator",
#     "Energy": "http://purl.oclc.org/NET/ssnx/qu/dim#Energy",
#     "foaf.name": "http://xmlns.com/foaf/0.1/name",
#     "Role": "https://schema.org/Role",
#     "hasSerialization": {
#       "@id": "http://www.opengis.net/ont/geosparql#hasSerialization",
#       "@type": "rdfs:Literal"
#     },
#     "hasTime": {
#       "@id": "owlTime:hasTime",
#       "@type": "@id"
#     },
#     "SF_SamplingFeature.sampledFeature": {
#       "@id": "http://def.isotc211.org/iso19156/2011/SamplingFeature#SF_SamplingFeature.sampledFeature",
#       "@type": "@id"
#     },
#     "rangeIncludes": "https://schema.org/rangeIncludes",
#     "Mass": "http://purl.oclc.org/NET/ssnx/qu/dim#Mass",
#     "location": {
#       "@id": "http://www.w3.org/2003/01/geo/wgs84_pos#location",
#       "@type": "@id"
#     },
#     "ComponentSpecification": "http://purl.org/linked-data/cube#ComponentSpecification",
#     "Scheme": "http://www.w3.org/2004/02/skos/core#Scheme",
#     "hasEnd": {
#       "@id": "owlTime:hasEnd",
#       "@type": "@id"
#     },
#     "rights": "dct:rights",
#     "TemporalEntity": "owlTime:TemporalEntity",
#     "hasBeginning": {
#       "@id": "owlTime:hasBeginning",
#       "@type": "@id"
#     },
#     "SF_SamplingFeature": "http://def.isotc211.org/iso19156/2011/SamplingFeature#SF_SamplingFeature",
#     "DimensionProperty": "http://purl.org/linked-data/cube#DimensionProperty",
#     "alt": "http://www.w3.org/2003/01/geo/wgs84_pos#alt",
#     "Acceleration": "http://purl.oclc.org/NET/ssnx/qu/dim#Acceleration",
#     "identifier": "dct:identifier",
#     "Quantity": "http://qudt.org/schema/qudt/Quantity",
#     "MassFlowRate": "http://purl.oclc.org/NET/ssnx/qu/dim#MassFlowRate",
#     "qu.QuantityKind": "http://purl.oclc.org/NET/ssnx/qu/qu#QuantityKind",
#     "SpatialObjectCollection": "http://www.opengis.net/ont/geosparql#SpatialObjectCollection",
#     "Distance": "http://purl.oclc.org/NET/ssnx/qu/dim#Distance",
#     "deprecated": "http://www.w3.org/2002/07/owl#deprecated",
#     "Radiance": "http://purl.oclc.org/NET/ssnx/qu/dim#Radiance",
#     "Duration": "owlTime:Duration",
#     "TIN": "http://www.opengis.net/ont/sf#TIN",
#     "SurfaceDensity": "http://purl.oclc.org/NET/ssnx/qu/dim#SurfaceDensity",
#     "isDefinedBy": "rdfs:isDefinedBy",
#     "wgs84.Point": "http://www.w3.org/2003/01/geo/wgs84_pos#Point",
#     "definition": "http://www.w3.org/2004/02/skos/core#definition",
#     "editorialNote": "http://www.w3.org/2004/02/skos/core#editorialNote",
#     "order": {
#       "@id": "http://purl.org/linked-data/cube#order",
#       "@type": "xsd:int"
#     },
#     "hasGeometry": {
#       "@id": "http://www.opengis.net/ont/geosparql#hasGeometry",
#       "@type": "@id"
#     },
#     "ssn.Property": "ssn:Property",
#     "sfContains": {
#       "@id": "http://www.opengis.net/ont/geosparql#sfContains",
#       "@type": "@id"
#     },
#     "title": "dct:title",
#     "Density": "http://purl.oclc.org/NET/ssnx/qu/dim#Density",
#     "LinearRing": "http://www.opengis.net/ont/sf#LinearRing",
#     "Molality": "http://purl.oclc.org/NET/ssnx/qu/dim#Molality",
#     "inXSDDateTimeStamp": {
#       "@id": "owlTime:inXSDDateTimeStamp",
#       "@type": "xsd:dateTimeStamp"
#     },
#     "MeasureProperty": "http://purl.org/linked-data/cube#MeasureProperty",
#     "PropertyKind": "http://purl.oclc.org/NET/ssnx/qu/qu#PropertyKind",
#     "SpatialObject": "http://www.opengis.net/ont/geosparql#SpatialObject",
#     "sliceStructure": {
#       "@id": "http://purl.org/linked-data/cube#sliceStructure",
#       "@type": "@id"
#     },
#     "NumberPerLength": "http://purl.oclc.org/NET/ssnx/qu/dim#NumberPerLength",
#     "lat": "http://www.w3.org/2003/01/geo/wgs84_pos#lat",
#     "VolumeFlowRate": "http://purl.oclc.org/NET/ssnx/qu/dim#VolumeFlowRate",
#     "SpecificEntropy": "http://purl.oclc.org/NET/ssnx/qu/dim#SpecificEntropy",
#     "CodedProperty": "http://purl.org/linked-data/cube#CodedProperty",
#     "slice": {
#       "@id": "http://purl.org/linked-data/cube#slice",
#       "@type": "@id"
#     },
#     "unit": {
#       "@id": "http://qudt.org/schema/qudt/unit",
#       "@type": "@id"
#     },
#     "date": "dct:date",
#     "seeAlso": "rdfs:seeAlso",
#     "ObservationGroup": "http://purl.org/linked-data/cube#ObservationGroup",
#     "DataSet": "http://purl.org/linked-data/cube#DataSet",
#     "comment": "rdfs:comment",
#     "PolyhedralSurface": "http://www.opengis.net/ont/sf#PolyhedralSurface",
#     "contributor": "dct:contributor",
#     "unitKind": {
#       "@id": "http://purl.oclc.org/NET/ssnx/qu/qu#unitKind",
#       "@type": "@id"
#     },
#     "dimension": {
#       "@id": "http://purl.org/linked-data/cube#dimension",
#       "@type": "@id"
#     },
#     "RadianceExposure": "http://purl.oclc.org/NET/ssnx/qu/dim#RadianceExposure",
#     "VelocityOrSpeed": "http://purl.oclc.org/NET/ssnx/qu/dim#VelocityOrSpeed",
#     "inXSDDate": {
#       "@id": "owlTime:inXSDDate",
#       "@type": "xsd:date"
#     },
#     "GFI_DomainFeature": "http://def.isotc211.org/iso19156/2011/GeneralFeatureInstance#GFI_DomainFeature",
#     "observation": {
#       "@id": "http://purl.org/linked-data/cube#observation",
#       "@type": "@id"
#     },
#     "Dimensionless": "http://purl.oclc.org/NET/ssnx/qu/dim#Dimensionless",
#     "Area": "http://purl.oclc.org/NET/ssnx/qu/dim#Area",
#     "Power": "http://purl.oclc.org/NET/ssnx/qu/dim#Power",
#     "OM_Observation": "http://def.isotc211.org/iso19156/2011/Observation#OM_Observation",
#     "prefLabel": "http://www.w3.org/2004/02/skos/core#prefLabel",
#     "Surface": "http://www.opengis.net/ont/sf#Surface",
#     "sliceKey": {
#       "@id": "http://purl.org/linked-data/cube#sliceKey",
#       "@type": "@id"
#     },
#     "inScheme": "http://www.w3.org/2004/02/skos/core#inScheme",
#     "dct.description": "dct:description",
#     "MultiCurve": "http://www.opengis.net/ont/sf#MultiCurve",
#     "hasQuantityKind": {
#       "@id": "http://qudt.org/schema/qudt/hasQuantityKind",
#       "@type": "@id"
#     },
#     "DataStructureDefinition": "http://purl.org/linked-data/cube#DataStructureDefinition",
#     "qb.Observation": "http://purl.org/linked-data/cube#Observation",
#     "EnergyDensity": "http://purl.oclc.org/NET/ssnx/qu/dim#EnergyDensity",
#     "unitType": {
#       "@id": "owlTime:unitType",
#       "@type": "@id"
#     },
#     "componentProperty": {
#       "@id": "http://purl.org/linked-data/cube#componentProperty",
#       "@type": "@id"
#     },
#     "sf.Geometry": "http://www.opengis.net/ont/sf#Geometry",
#     "schema.Person": "https://schema.org/Person",
#     "schema.name": "https://schema.org/name",
#     "QuantityKind": "http://qudt.org/schema/qudt/QuantityKind",
#     "sosa": "http://www.w3.org/ns/sosa/",
#     "ssn-system": "ssn:systems/",
#     "ssn": "http://www.w3.org/ns/ssn/",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "iliad": "https://w3id.org/iliad/property/",
#     "jf-property": "https://w3id.org/iliad/jellyfish/property/",
#     "jf-density": "jf-property:densityOfJF/",
#     "geojson": "https://purl.org/geojson/vocab#",
#     "oa": "http://www.w3.org/ns/oa#",
#     "dct": "http://purl.org/dc/terms/",
#     "owlTime": "http://www.w3.org/2006/time#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "@version": 1.1
#   },
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "id": "Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Rhizostoma pulmo",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           34.790955,
#           32.355448
#         ]
#       },
#       "properties": {
#         "occurrence": "Jellyfish_in_Israeli_Mediterranean_coast",
#         "eventDate_ori": "01/07/2011 10:00",
#         "date": "01/07/2011",
#         "dateFix": "07/01/2011",
#         "time": "10:00",
#         "eventDate": "2011-07-01T10:00:00",
#         "decimalLongitude_ori": "34,790,955",
#         "decimalLatitude_ori": "32,355,448",
#         "scientificName": "Rhizostoma pulmo",
#         "occurrenceStatus": "present",
#         "basisOfRecord": "HumanObservation",
#         "scientificNameID": "http://marinespecies.org/aphia.php?p=taxdetails&id=135299",
#         "recordedBy": 361,
#         "quantificationMethod": "Fishing",
#         "organismQuantity": "Swarm",
#         "organismQuantityType": "Individuals",
#         "sampleSizeUnit": "cm",
#         "sampleSizeValue": "0-10",
#         "MachineObservation": "-",
#         "eventType": 0,
#         "coordinateUncertaintyInMeters": 10000,
#         "strandedJellyfish": 1,
#         "goldUser": 1,
#         "Stinging_Water": "Unspecified",
#         "distanceWalkedinmeters": "-",
#         "obsID": 3,
#         "Location_20_Zones_ID": 10,
#         "Distance_from_coast": "1000-10000",
#         "Quantity_Reported": 50
#       }
#     }
#   ],
#   "numberMatched": 25294,
#   "numberReturned": 1,
#   "links": [
#     {
#       "type": "application/geo+json",
#       "rel": "self",
#       "title": "This document as GeoJSON",
#       "href": "http://localhost:5002/collections/my-observations-schema.org/items?f=json&limit=1"
#     },
#     {
#       "rel": "alternate",
#       "type": "application/ld+json",
#       "title": "This document as RDF (JSON-LD)",
#       "href": "http://localhost:5002/collections/my-observations-schema.org/items?f=jsonld&limit=1"
#     },
#     {
#       "type": "text/html",
#       "rel": "alternate",
#       "title": "This document as HTML",
#       "href": "http://localhost:5002/collections/my-observations-schema.org/items?f=html&limit=1"
#     },
#     {
#       "type": "application/geo+json",
#       "rel": "prev",
#       "title": "Items (prev)",
#       "href": "http://localhost:5002/collections/my-observations-schema.org/items?offset=0&limit=1"
#     },
#     {
#       "type": "application/geo+json",
#       "rel": "next",
#       "title": "Items (next)",
#       "href": "http://localhost:5002/collections/my-observations-schema.org/items?offset=2&limit=1"
#     },
#     {
#       "type": "application/json",
#       "title": "Observations",
#       "rel": "collection",
#       "href": "http://localhost:5002/collections/my-observations-schema.org"
#     }
#   ],
#   "timeStamp": "2024-11-17T23:07:10.087764Z"
# }
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix geojson: <https://purl.org/geojson/vocab#> .
# @prefix ns1: <http://www.iana.org/assignments/> .
# @prefix oa: <http://www.w3.org/ns/oa#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# [] a geojson:FeatureCollection ;
#     rdfs:seeAlso [ rdfs:label "This document as RDF (JSON-LD)" ;
#             dcterms:type "application/ld+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/alternate> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org/items?f=jsonld&limit=1> ],
#         [ rdfs:label "Items (next)" ;
#             dcterms:type "application/geo+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/next> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org/items?offset=2&limit=1> ],
#         [ rdfs:label "This document as GeoJSON" ;
#             dcterms:type "application/geo+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/self> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org/items?f=json&limit=1> ],
#         [ rdfs:label "This document as HTML" ;
#             dcterms:type "text/html" ;
#             ns1:relation <http://www.iana.org/assignments/relation/alternate> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org/items?f=html&limit=1> ],
#         [ rdfs:label "Observations" ;
#             dcterms:type "application/json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/collection> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org> ],
#         [ rdfs:label "Items (prev)" ;
#             dcterms:type "application/geo+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/prev> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-schema.org/items?offset=0&limit=1> ] .

# %%
data3 = {
   '@id': 'Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo',

   'geometry': {'type': 'Point', 'coordinates': [34.634776, 31.80691]},

 'featureType': 'sosa:Observation',
   'properties': {'occurrence': 'Jellyfish_in_Israeli_Mediterranean_coast',
    'eventDate_ori': '01/07/2011 9:00',
    'date': '01/07/2011',
    'dateFix': '07/01/2011',
    'time': '9:00',
    'eventDate': '2011-07-01T09:00:00',
    'decimalLongitude_ori': 34.634776,
    'decimalLatitude_ori': 31.80691,
    'scientificName': 'Rhizostoma pulmo',
    'occurrenceStatus': 'present',
    'basisOfRecord': 'HumanObservation',
    'scientificNameID': 'http://marinespecies.org/aphia.php?p=taxdetails&id=135299',
    'recordedBy': 527,
    'quantificationMethod': 'Other',
    'organismQuantity': 'Some',
    'organismQuantityType': 'Individuals',
    'sampleSizeUnit': 'cm',
    'sampleSizeValue': '10-30',
    'MachineObservation': '-',
    'eventType': 0,
    'coordinateUncertaintyInMeters': 1000,
    'strandedJellyfish': 1,
    'goldUser': 1,
    'Stinging_Water': 'Unspecified',
    'distanceWalkedinmeters': '-',
    'obsID': 1,
    'Location_20_Zones_ID': 18,
    'Distance_from_coast': '200-1000',
    'Quantity_Reported': 10}}

# %%
#GeoJSON is nicely handled by the map implementations. As the current data is a collection, one could navigate through it with  but can include various data in properties of 'feature'and we'll parse it into 
#g_ttl2, g2 = json_to_rdf(data2)

# data_with_context2 = data3
# data_with_context2["@context"] = 'https://ogcincubator.github.io/iliad-apis-features/build/annotated/hosted/iliad/api/features/iliad-jellyfish/context.jsonld'
data_with_context2 = {
    "@context": context["@context"],
    "@graph": data3
    }
    # Convert JSON-LD to RDF
g2 = Graph()
g2.parse(data=json.dumps(data_with_context2), format='json-ld')

    # Print the RDF data
g_ttl2 = g2.serialize(format='turtle')
print(g_ttl2)
# Out:
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix geojson: <https://purl.org/geojson/vocab#> .
# @prefix iliad: <https://w3id.org/iliad/property/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix sosa: <http://www.w3.org/ns/sosa/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://w3id.org/iliad/jellyfish/observation/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo> a sosa:Observation ;
#     dct:date "01/07/2011" ;
#     dct:time "9:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.463478e+01 3.180691e+01 ) ] ;
#     iliad:sampleSizeValue "10-30" .

# %%
#as there is no daata in the graph, we expect it was not properly mapped to OIM, but lets try to query data
# Execute the SPARQL query on the RDF graph

query = """
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX geojson: <https://purl.org/geojson/vocab#>

SELECT ?observation ?coordinates ?latitude ?longitude
WHERE {
# ?observation a sosa:Observation ;
    geojson:geometry ?geometry .
# ?geometry geojson:coordinates ?coordinates .
# ?coordinates rdf:first ?latitude ;
        rdf:rest/rdf:first ?longitude .
}
"""

results = data_graph.query(query)

# Process and print the results
output = ""
for result in results:
    observation = result["observation"]
    quantity = result["quantity"]
    coordinates = result["coordinates"]
    latitude = result["latitude"]
    longitude = result["longitude"]
    species = result["species"]
    output = output + f"Observation: {observation}, Quantity: {quantity}, Coordinates: {latitude} {longitude}, Species: {species}"

len(results)
# Out:
# 0

# %%
data3=requests.get('http://localhost:5002/collections/my-observations-linked/items?f=json&offset=0&limit=100').json()

map_features(data=data3, center=[31.80691, 34.634776],zoom=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc3c363962dc0a0ac2e017a2e5a48827 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc3c363962dc0a0ac2e017a2e5a48827&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc3c363962dc0a0ac2e017a2e5a48827 = L.map(
#                 &quot;map_fc3c363962dc0a0ac2e017a2e5a48827&quot;,
#                 {
#                     center: [31.80691, 34.634776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b6037bb2729c7415893e941e78d5a5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b6037bb2729c7415893e941e78d5a5a.addTo(map_fc3c363962dc0a0ac2e017a2e5a48827);
#
#
#
#         function geo_json_bd0c6cab3b866ba72c44731939851eb4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bd0c6cab3b866ba72c44731939851eb4 = L.geoJson(null, {
#                 onEachFeature: geo_json_bd0c6cab3b866ba72c44731939851eb4_onEachFeature,
#
#         });
#
#         function geo_json_bd0c6cab3b866ba72c44731939851eb4_add (data) {
#             geo_json_bd0c6cab3b866ba72c44731939851eb4
#                 .addData(data);
#         }
#             geo_json_bd0c6cab3b866ba72c44731939851eb4_add({&quot;@context&quot;: &quot;https://ogcincubator.github.io/iliad-apis-features/build/annotated/hosted/iliad/api/features/iliad-jellyfish/context.jsonld&quot;, &quot;features&quot;: [{&quot;featureType&quot;: &quot;sosa:Observation&quot;, &quot;geometry&quot;: {&quot;coordinates&quot;: [34.634776, 31.80691], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast140725.37530-60Rhopilema_nomadica&quot;, &quot;properties&quot;: {&quot;Distance_from_coast&quot;: &quot;200-1000&quot;, &quot;Location_20_Zones_ID&quot;: 18, &quot;MachineObservation&quot;: &quot;-&quot;, &quot;Quantity_Reported&quot;: 10, &quot;Stinging_Water&quot;: &quot;Unspecified&quot;, &quot;basisOfRecord&quot;: &quot;HumanObservation&quot;, &quot;coordinateUncertaintyInMeters&quot;: 1000, &quot;date&quot;: &quot;01/07/2011&quot;, &quot;dateFix&quot;: &quot;07/01/2011&quot;, &quot;distanceWalkedinmeters&quot;: &quot;-&quot;, &quot;eventDate&quot;: &quot;2011-07-01T09:00:00&quot;, &quot;eventDate_ori&quot;: &quot;01/07/2011 09:00&quot;, &quot;eventType&quot;: 0, &quot;goldUser&quot;: 1, &quot;obsID&quot;: 1, &quot;occurrence&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast&quot;, &quot;occurrenceStatus&quot;: &quot;present&quot;, &quot;organismQuantity&quot;: &quot;Some&quot;, &quot;organismQuantityType&quot;: &quot;Individuals&quot;, &quot;quantificationMethod&quot;: &quot;Other&quot;, &quot;recordedBy&quot;: 527, &quot;sampleSizeUnit&quot;: &quot;cm&quot;, &quot;sampleSizeValue&quot;: &quot;30-60&quot;, &quot;scientificName&quot;: &quot;Rhopilema nomadica&quot;, &quot;scientificNameID&quot;: &quot;https://marinespecies.org/aphia.php?p=taxdetails\u0026id=232032&quot;, &quot;strandedJellyfish&quot;: 1, &quot;time&quot;: &quot;09:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;featureType&quot;: &quot;sosa:Observation&quot;, &quot;geometry&quot;: {&quot;coordinates&quot;: [34.634776, 31.80691], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo&quot;, &quot;properties&quot;: {&quot;Distance_from_coast&quot;: &quot;200-1000&quot;, &quot;Location_20_Zones_ID&quot;: 18, &quot;MachineObservation&quot;: &quot;-&quot;, &quot;Quantity_Reported&quot;: 10, &quot;Stinging_Water&quot;: &quot;Unspecified&quot;, &quot;basisOfRecord&quot;: &quot;HumanObservation&quot;, &quot;coordinateUncertaintyInMeters&quot;: 1000, &quot;date&quot;: &quot;01/07/2011&quot;, &quot;dateFix&quot;: &quot;07/01/2011&quot;, &quot;distanceWalkedinmeters&quot;: &quot;-&quot;, &quot;eventDate&quot;: &quot;2011-07-01T09:00:00&quot;, &quot;eventDate_ori&quot;: &quot;01/07/2011 09:00&quot;, &quot;eventType&quot;: 0, &quot;goldUser&quot;: 1, &quot;obsID&quot;: 1, &quot;occurrence&quot;: &quot;Jellyfish_in_Israeli_Mediterranean_coast&quot;, &quot;occurrenceStatus&quot;: &quot;present&quot;, &quot;organismQuantity&quot;: &quot;Some&quot;, &quot;organismQuantityType&quot;: &quot;Individuals&quot;, &quot;quantificationMethod&quot;: &quot;Other&quot;, &quot;recordedBy&quot;: 527, &quot;sampleSizeUnit&quot;: &quot;cm&quot;, &quot;sampleSizeValue&quot;: &quot;Oct-30&quot;, &quot;scientificName&quot;: &quot;Rhizostoma pulmo&quot;, &quot;scientificNameID&quot;: &quot;http://marinespecies.org/aphia.php?p=taxdetails\u0026id=135299&quot;, &quot;strandedJellyfish&quot;: 1, &quot;time&quot;: &quot;09:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;featureType&quot;: &quot;sosa:Observation&quot;, &quot;geometry&quot;: {&quot;coordinates&quot;: [34.634776, 31.80691], &quot

# %%
g3 = Graph()
g3.parse(data=json.dumps(data3), format='json-ld')

    # Print the RDF data
g_ttl3 = g3.serialize(format='turtle')
print(g_ttl3)
# Out:
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix geojson: <https://purl.org/geojson/vocab#> .
# @prefix iliad: <https://w3id.org/iliad/property/> .
# @prefix ns1: <http://www.iana.org/assignments/> .
# @prefix oa: <http://www.w3.org/ns/oa#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sosa: <http://www.w3.org/ns/sosa/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1040728.37530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.488873e+01 3.249201e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1140728.37511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.473905e+01 3.2024e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.473905e+01 3.2024e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.463478e+01 3.180691e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.463478e+01 3.180691e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.463478e+01 3.180691e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.750-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "18:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.7530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "18:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1540728.50-10Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Aurelia_aurita> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1740729.416666666711232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.475863e+01 3.206051e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1840729.416666666711232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.492035e+01 3.262231e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.45833333330-10Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.50-10Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.54166666670-10Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666711232Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Aurelia_aurita> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.54166666670-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.541666666730-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "05/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.488873e+01 3.249201e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.488873e+01 3.249201e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast244073030-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "00:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666730-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666760+Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue 60 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2640730.7530-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "18:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2740730.6250-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.473905e+01 3.2024e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2840730.666666666711232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.474021e+01 3.202824e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast294073011232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "06/07/2011" ;
#     dct:time "00:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3040731.458333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3140731.666666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.488873e+01 3.249201e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.6250-10Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62530-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3340731.37511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.491751e+01 3.261468e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.416666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "01/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cassiopea_andromeda> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.492035e+01 3.262231e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cotylorhiza_tuberculata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.492035e+01 3.262231e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3540731.3750-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3640731.70833333330-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "23:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "07/07/2011" ;
#     dct:time "23:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3940732.37511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4040732.333333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "08:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4140732.62511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4240732.541666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4340732.54166666670-10Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast440726.458333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "02/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4440732.416666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4540732.583333333330-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.492363e+01 3.264359e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.492363e+01 3.264359e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4740732.416666666711232Cassiopea_andromeda> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4840732.666666666711232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 60 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 60 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.79166666670-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "19:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.791666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "19:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5340732.666666666730-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast540727.291666666730-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "03/07/2011" ;
#     dct:time "07:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.70833333330-10Mnemiopsis_Leidyi> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.708333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5540732.458333333330-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "11:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "14:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5740732.333333333311232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "08:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5840732.62511232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "15:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.479095e+01 3.235545e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5940732.541666666711232Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "13:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333311232Phyllorhiza_punctata> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333322190Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "17:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6140732.416666666760+Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "10:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 60 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6240732.79166666670-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "19:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6340732.66666666670-> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue 0 .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "03/07/2011" ;
#     dct:time "18:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "03/07/2011" ;
#     dct:time "18:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.456848e+01 3.180974e+01 ) ] ;
#     iliad:sampleSizeValue "30-60" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6440732.666666666711232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "08/07/2011" ;
#     dct:time "16:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.474021e+01 3.202824e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.50-30Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "0-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.511232Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "12:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.494339e+01 3.284952e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast840728.37522190Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.491751e+01 3.261468e+01 ) ] ;
#     iliad:sampleSizeValue "Oct-30" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-10Rhizostoma_pulmo> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.487755e+01 3.2439e+01 ) ] ;
#     iliad:sampleSizeValue "0-10" .
#
# <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-60Rhopilema_nomadica> a sosa:Observation,
#         geojson:Feature ;
#     dct:date "04/07/2011" ;
#     dct:time "09:00" ;
#     geojson:geometry [ a geojson:Point ;
#             geojson:coordinates ( 3.487755e+01 3.2439e+01 ) ] ;
#     iliad:sampleSizeValue "0-60" .
#
# [] a geojson:FeatureCollection ;
#     rdfs:seeAlso [ rdfs:label "Observations linked" ;
#             dct:type "application/json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/collection> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-linked> ],
#         [ rdfs:label "This document as RDF (JSON-LD)" ;
#             dct:type "application/ld+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/alternate> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-linked/items?f=jsonld&limit=100> ],
#         [ rdfs:label "This document as HTML" ;
#             dct:type "text/html" ;
#             ns1:relation <http://www.iana.org/assignments/relation/alternate> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-linked/items?f=html&limit=100> ],
#         [ rdfs:label "Items (next)" ;
#             dct:type "application/geo+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/next> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-linked/items?offset=100&limit=100> ],
#         [ rdfs:label "This document as GeoJSON" ;
#             dct:type "application/geo+json" ;
#             ns1:relation <http://www.iana.org/assignments/relation/self> ;
#             oa:hasTarget <http://localhost:5002/collections/my-observations-linked/items?f=json&limit=100> ] ;
#     sosa:hasMember <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1040728.37530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1140728.37511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.750->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.7530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1540728.50-10Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Aurelia_aurita>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1740729.416666666711232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1840729.416666666711232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.45833333330-10Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.50-10Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.54166666670-10Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666711232Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Aurelia_aurita>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.54166666670->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.541666666730-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast244073030-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666730-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666760+Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2640730.7530-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2740730.6250->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2840730.666666666711232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast294073011232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3040731.458333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3140731.666666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.6250-10Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62530-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3340731.37511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.416666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cassiopea_andromeda>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cotylorhiza_tuberculata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3540731.3750->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3640731.70833333330->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3940732.37511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4040732.333333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4140732.62511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4240732.541666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4340732.54166666670-10Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast440726.458333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4440732.416666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4540732.583333333330-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4740732.416666666711232Cassiopea_andromeda>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4840732.666666666711232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.79166666670->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.791666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5340732.666666666730-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast540727.291666666730-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.70833333330-10Mnemiopsis_Leidyi>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.708333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5540732.458333333330-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5740732.333333333311232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5840732.62511232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5940732.541666666711232Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333311232Phyllorhiza_punctata>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333322190Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6140732.416666666760+Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6240732.79166666670->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6340732.66666666670->,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6440732.666666666711232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.50-30Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.511232Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast840728.37522190Rhopilema_nomadica>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-10Rhizostoma_pulmo>,
#         <file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-60Rhopilema_nomadica> .

# %%
# Define the SPARQL query to filter out specific types of observations
query = """
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX jf-property: <https://w3id.org/iliad/jellyfish/property/>
PREFIX geojson: <https://purl.org/geojson/vocab#>
PREFIX iliad: <https://w3id.org/iliad/property/>

SELECT ?observation ?sampleSize ?coordinates ?species ?latitude ?longitude
WHERE {
# ?observation a sosa:Observation ;
    geojson:geometry ?geometry ;
    iliad:sampleSizeValue ?sampleSize .
# ?geometry geojson:coordinates ?coordinates .
# ?coordinates rdf:first ?latitude ;
        rdf:rest/rdf:first ?longitude .
}
"""

# Execute the SPARQL query on the RDF graph
results = g3.query(query)

# Process and print the results
output = ""
for result in results:
    observation = result["observation"]
    quantity = result["sampleSize"]
    coordinates = result["coordinates"]
    latitude = result["latitude"]
    longitude = result["longitude"]
    species = result["species"]
    output = output + "\n" + f"Observation: {observation}, Quantity: {quantity}, Coordinates: {latitude} {longitude}, Species: {species}"

print(output)
# Out:
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.634776 31.80691, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.634776 31.80691, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast140725.37511232Phyllorhiza_punctata, Quantity: Oct-30, Coordinates: 34.634776 31.80691, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.88873 32.492007, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast240725.37511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.88873 32.492007, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.416666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Rhizostoma_pulmo, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast340725.41666666670-10Phyllorhiza_punctata, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast440726.458333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast540727.291666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast640727.7530-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.50-30Rhopilema_nomadica, Quantity: 0-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast740728.511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast840728.37522190Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.917511 32.614676, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-60Rhopilema_nomadica, Quantity: 0-60, Coordinates: 34.877548 32.438997, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast940728.3750-10Rhizostoma_pulmo, Quantity: 0-10, Coordinates: 34.877548 32.438997, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1040728.37530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.88873 32.492007, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1140728.37511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1240728.511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.73905 32.023998, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1340728.583333333330-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.73905 32.023998, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.7530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1440728.750-, Quantity: 0, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1540728.50-10Rhopilema_nomadica, Quantity: 0-10, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Aurelia_aurita, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1640729.583333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1740729.416666666711232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.758632 32.060514, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1840729.416666666711232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.92035 32.622308, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.458333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast1940729.45833333330-10Phyllorhiza_punctata, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2040729.50-10Phyllorhiza_punctata, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.54166666670-10Rhizostoma_pulmo, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2140729.541666666711232Phyllorhiza_punctata, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Aurelia_aurita, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2240729.62511232Phyllorhiza_punctata, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.54166666670-, Quantity: 0, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2340729.541666666730-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast244073030-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666760+Rhopilema_nomadica, Quantity: 60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2540730.666666666730-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2640730.7530-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2740730.6250-, Quantity: 0, Coordinates: 34.73905 32.023998, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast2840730.666666666711232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.740208 32.028245, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast294073011232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3040731.458333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3140731.666666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.88873 32.492007, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.62530-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3240731.6250-10Phyllorhiza_punctata, Quantity: 0-10, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3340731.37511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.917511 32.614676, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cotylorhiza_tuberculata, Quantity: Oct-30, Coordinates: 34.92035 32.622308, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3440731.37511232Cassiopea_andromeda, Quantity: Oct-30, Coordinates: 34.92035 32.622308, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3540731.3750-, Quantity: 0, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3640731.70833333330-, Quantity: 0, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3740731.708333333330-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3840731.958333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast3940732.37511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4040732.333333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4140732.62511232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4240732.541666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4340732.54166666670-10Rhopilema_nomadica, Quantity: 0-10, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4440732.416666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4540732.583333333330-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.923631 32.643589, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4640732.530-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.923631 32.643589, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4740732.416666666711232Cassiopea_andromeda, Quantity: Oct-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4840732.666666666711232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhopilema_nomadica, Quantity: 60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast4940732.666666666760+Rhizostoma_pulmo, Quantity: 60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5040732.541666666730-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.791666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5140732.79166666670-, Quantity: 0, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhopilema_nomadica, Quantity: 30-60, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5240732.666666666730-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5340732.666666666730-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.708333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5440732.70833333330-10Mnemiopsis_Leidyi, Quantity: 0-10, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5540732.458333333330-60Rhizostoma_pulmo, Quantity: 30-60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5640732.583333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5740732.333333333311232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.94339 32.849519, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5840732.62511232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.790955 32.355448, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast5940732.541666666711232Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333322190Rhopilema_nomadica, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6040732.708333333311232Phyllorhiza_punctata, Quantity: Oct-30, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6140732.416666666760+Rhopilema_nomadica, Quantity: 60, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6240732.79166666670-, Quantity: 0, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6340732.66666666670-, Quantity: 0, Coordinates: 34.568481 31.809739, Species: None
# Observation: file:///Users/piotr/repos/Iliad/data_access_api/examples/Observations_Features/Jellyfish_in_Israeli_Mediterranean_coast6440732.666666666711232Rhizostoma_pulmo, Quantity: Oct-30, Coordinates: 34.740208 32.028245, Species: None

# %%
# !pip install rdflib networkx matplotlib
# Out:
# Requirement already satisfied: rdflib in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (7.1.1)
# Requirement already satisfied: networkx in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (3.4.2)
# Requirement already satisfied: matplotlib in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (3.9.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from rdflib) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/piotr/repos/Iliad/data_access_api/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import rdflib
import networkx as nx
import matplotlib.pyplot as plt

# Convert RDF graph to NetworkX graph
G = nx.DiGraph()

for s, p, o in g:
    G.add_edge(s, o, label=p)

# Draw the graph
pos = nx.spring_layout(G)
edge_labels = nx.get_edge_attributes(G, 'label')

plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, node_size=300, node_color="skyblue", font_size=10, font_weight="bold", arrows=True)
#nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title("RDF Graph Visualization")
plt.show()
